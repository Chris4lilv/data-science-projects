# %%
import pandas as pd
import numpy as np
import time

# %% [markdown]
# **Turn dataset into vertical representation**

# %%
########################### Vars
#################################################################################
TARGET = 'sales'         # Our main target
END_TRAIN = 1913         # Last day in train set
MAIN_INDEX = ['id','d']  # We can identify item by these columns

# %%
df = pd.read_csv('sales_train_validation.csv')

# %%
index_columns = ['id','item_id','dept_id','cat_id','store_id','state_id']
train_df = pd.melt(df,
                  id_vars = index_columns, 
                  var_name = 'd', 
                  value_name = TARGET)

train_df[train_df['id']=='HOBBIES_1_001_CA_1_validation'].iloc[:10]
# Out:
#                                    id        item_id    dept_id   cat_id  \
# 0       HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 30490   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 60980   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 91470   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 121960  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 152450  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 182940  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 213430  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 243920  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 274410  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
#
#        store_id state_id     d  sales
# 0          CA_1       CA   d_1      0
# 30490      CA_1       CA   d_2      0
# 60980      CA_1       CA   d_3      0
# 91470      CA_1       CA   d_4      0
# 121960     CA_1       CA   d_5      0
# 152450     CA_1       CA   d_6      0
# 182940     CA_1       CA   d_7      0
# 213430     CA_1       CA   d_8      0
# 243920     CA_1       CA   d_9      0
# 274410     CA_1       CA  d_10      0

# %%
# group and shift in loop
temp_df = train_df[['id','d',TARGET]]

start_time = time.time()
for i in range(1,8):
    print('Shifting:', i)
    temp_df['lag_'+str(i)] = temp_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(i))
    
print('%0.2f min: Time for loops' % ((time.time() - start_time) / 60))
# Out:
# Shifting: 1
# d:\python demo\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# Shifting: 2
# Shifting: 3
# Shifting: 4
# Shifting: 5
# Shifting: 6
# Shifting: 7
# 7.10 min: Time for loops

# %%
# # Or same in "compact" manner
# LAG_DAYS = [col for col in range(1,8)]
# temp_df = train_df[['id','d',TARGET]]

# start_time = time.time()
# temp_df = temp_df.assign(**{
#         '{}_lag_{}'.format(col, l): temp_df.groupby(['id'])[col].transform(lambda x: x.shift(l))
#         for l in LAG_DAYS
#         for col in [TARGET]
#     })

# print('%0.2f min: Time for bulk shift' % ((time.time() - start_time) / 60))

# %%
temp_df[temp_df['id']=='HOBBIES_1_001_CA_1_validation'].iloc[:10]
# Out:
#                                    id     d  sales  lag_1  lag_2  lag_3  \
# 0       HOBBIES_1_001_CA_1_validation   d_1      0    NaN    NaN    NaN
# 30490   HOBBIES_1_001_CA_1_validation   d_2      0    0.0    NaN    NaN
# 60980   HOBBIES_1_001_CA_1_validation   d_3      0    0.0    0.0    NaN
# 91470   HOBBIES_1_001_CA_1_validation   d_4      0    0.0    0.0    0.0
# 121960  HOBBIES_1_001_CA_1_validation   d_5      0    0.0    0.0    0.0
# 152450  HOBBIES_1_001_CA_1_validation   d_6      0    0.0    0.0    0.0
# 182940  HOBBIES_1_001_CA_1_validation   d_7      0    0.0    0.0    0.0
# 213430  HOBBIES_1_001_CA_1_validation   d_8      0    0.0    0.0    0.0
# 243920  HOBBIES_1_001_CA_1_validation   d_9      0    0.0    0.0    0.0
# 274410  HOBBIES_1_001_CA_1_validation  d_10      0    0.0    0.0    0.0
#
#         lag_4  lag_5  lag_6  lag_7
# 0         NaN    NaN    NaN    NaN
# 30490     NaN    NaN    NaN    NaN
# 60980     NaN    NaN    NaN    NaN
# 91470     NaN    NaN    NaN    NaN
# 121960    0.0    NaN    NaN    NaN
# 152450    0.0    0.0    NaN    NaN
# 182940    0.0    0.0    0.0    NaN
# 213430    0.0    0.0    0.0    0.0
# 243920    0.0    0.0    0.0    0.0
# 274410    0.0    0.0    0.0    0.0

# %% [markdown]
# ***Here we can clearly see a pattern so that you could easily understand the purpose of creating lag features: it's to get relevant informations of the last 7 days***

# %% [markdown]
# ### Rolling lags
#
# *This is to find information more than the most recent 7 days because the memory limit won't allow us to create many lag features*

# %%
start_time = time.time()

for i in [14,30,60]:
    print('Rolling period:', i)
    temp_df['rolling_mean_'+str(i)] = temp_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(1).rolling(i).mean())
    temp_df['rolling_std_'+str(i)]  = temp_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(1).rolling(i).std())

# lambda x: x.shift(1)
# 1 day shift will serve only to predict day 1914
# for other days you have to shift PREDICT_DAY-1913

# Such aggregations will help us to restore
# at least part of the information for our model
# and out of 14+30+60->104 columns we can have just 6
# with valuable information (hope it is sufficient)
# you can also aggregate by max/skew/median etc 
# also you can try other rolling periods 180,365 etc
print('%0.2f min: Time for loop' % ((time.time() - start_time) / 60))
# Out:
# Rolling period: 14
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-e0eb183a35e3> in <module>
#       4     print('Rolling period:', i)
#       5     temp_df['rolling_mean_'+str(i)] = temp_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(1).rolling(i).mean())
# ----> 6     temp_df['rolling_std_'+str(i)]  = temp_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(1).rolling(i).std())
#       7
#       8 # lambda x: x.shift(1)
#
# d:\python demo\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# d:\python demo\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# d:\python demo\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     361
#     362         if isinstance(obj, NDFrame):
# --> 363             obj._consolidate_inplace()
#     364
#     365         self.level = level
#
# d:\python demo\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5250             self._data = self._data.consolidate()
#    5251
# -> 5252         self._protect_consolidate(f)
#    5253
#    5254     def _consolidate(self, inplace=False):
#
# d:\python demo\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5239         """
#    5240         blocks_before = len(self._data.blocks)
# -> 5241         result = f()
#    5242         if len(self._data.blocks) != blocks_before:
#    5243             self._clear_item_cache()
#
# d:\python demo\lib\site-packages\pandas\core\generic.py in f()
#    5248
#    5249         def f():
# -> 5250             self._data = self._data.consolidate()
#    5251
#    5252         self._protect_consolidate(f)
#
# d:\python demo\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     930         bm = self.__class__(self.blocks, self.axes)
#     931         bm._is_consolidated = False
# --> 932         bm._consolidate_inplace()
#     933         return bm
#     934
#
# d:\python demo\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     935     def _consolidate_inplace(self):
#     936         if not self.is_consolidated():
# --> 937             self.blocks = tuple(_consolidate(self.blocks))
#     938             self._is_consolidated = True
#     939             self._known_consolidated = True
#
# d:\python demo\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1911     for (_can_consolidate, dtype), group_blocks in grouper:
#    1912         merged_blocks = _merge_blocks(
# -> 1913             list(group_blocks), dtype=dtype, _can_consolidate=_can_consolidate
#    1914         )
#    1915         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#
# d:\python demo\lib\site-packages\pandas\core\internals\blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3321
#    3322         argsort = np.argsort(new_mgr_locs)
# -> 3323         new_values = new_values[argsort]
#    3324         new_mgr_locs = new_mgr_locs[argsort]
#    3325
#
# MemoryError: Unable to allocate 3.48 GiB for an array with shape (8, 58327370) and data type float64

# %%
temp_df[temp_df['id']=='HOBBIES_1_001_CA_1_validation'].iloc[:-40]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5f7a570816d3> in <module>
# ----> 1 temp_df[temp_df['id']=='HOBBIES_1_001_CA_1_validation'].iloc[:-40]
#
# NameError: name 'temp_df' is not defined

# %%
lags_roll = pd.read_pickle('lags_df_28.pkl')

# %%
lags_roll
# Out:
#                                      id     d  sales  sales_lag_28  \
# 0         HOBBIES_1_008_CA_1_validation     1   12.0           NaN
# 1         HOBBIES_1_009_CA_1_validation     1    2.0           NaN
# 2         HOBBIES_1_010_CA_1_validation     1    0.0           NaN
# 3         HOBBIES_1_012_CA_1_validation     1    0.0           NaN
# 4         HOBBIES_1_015_CA_1_validation     1    4.0           NaN
# ...                                 ...   ...    ...           ...
# 46881672    FOODS_3_823_WI_3_validation  1941    NaN           1.0
# 46881673    FOODS_3_824_WI_3_validation  1941    NaN           0.0
# 46881674    FOODS_3_825_WI_3_validation  1941    NaN           0.0
# 46881675    FOODS_3_826_WI_3_validation  1941    NaN           3.0
# 46881676    FOODS_3_827_WI_3_validation  1941    NaN           0.0
#
#           sales_lag_29  sales_lag_30  sales_lag_31  sales_lag_32  \
# 0                  NaN           NaN           NaN           NaN
# 1                  NaN           NaN           NaN           NaN
# 2                  NaN           NaN           NaN           NaN
# 3                  NaN           NaN           NaN           NaN
# 4                  NaN           NaN           NaN           NaN
# ...                ...           ...           ...           ...
# 46881672           0.0           0.0           1.0           0.0
# 46881673           1.0           0.0           0.0           0.0
# 46881674           1.0           0.0           0.0           1.0
# 46881675           1.0           3.0           0.0           1.0
# 46881676           0.0           0.0           0.0           0.0
#
#           sales_lag_33  sales_lag_34  ...  rolling_mean_tmp_1_30  \
# 0                  NaN           NaN  ...                    NaN
# 1                  NaN           NaN  ...                    NaN
# 2                  NaN           NaN  ...                    NaN
# 3                  NaN           NaN  ...                    NaN
# 4                  NaN           NaN  ...                    NaN
# ...                ...           ...  ...                    ...
# 46881672           0.0           0.0  ...                    NaN
# 46881673           0.0           0.0  ...                    NaN
# 46881674           0.0           2.0  ...                    NaN
# 46881675           0.0           0.0  ...                    NaN
# 46881676           0.0           0.0  ...                    NaN
#
#           rolling_mean_tmp_1_60  rolling_mean_tmp_7_7  rolling_mean_tmp_7_14  \
# 0                           NaN                   NaN                    NaN
# 1                           NaN                   NaN                    NaN
# 2                           NaN                   NaN                    NaN
# 3                           NaN                   NaN                    NaN
# 4                           NaN                   NaN                    NaN
# ...                         ...                   ...                    ...
# 46881672                    NaN                   NaN                    NaN
# 46881673                    NaN                   NaN                    NaN
# 46881674                    NaN                   NaN                    NaN
# 46881675                    NaN                   NaN                    NaN
# 46881676                    NaN                   NaN                    NaN
#
#           rolling_mean_tmp_7_30  rolling_mean_tmp_7_60  rolling_mean_tmp_14_7  \
# 0                           NaN                    NaN                    NaN
# 1                           NaN                    NaN                    NaN
# 2                           NaN                    NaN                    NaN
# 3                           NaN                    NaN                    NaN
# 4                           NaN                    NaN                    NaN
# ...                         ...                    ...                    ...
# 46881672                    NaN                    NaN                    NaN
# 46881673                    NaN                    NaN                    NaN
# 46881674                    NaN                    NaN                    NaN
# 46881675                    NaN                    NaN                    NaN
# 46881676                    NaN                    NaN                    NaN
#
#           rolling_mean_tmp_14_14  rolling_mean_tmp_14_30  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
# ...                          ...                     ...
# 46881672                     NaN                     NaN
# 46881673                     NaN                     NaN
# 46881674                     NaN                     NaN
# 46881675                     NaN                     NaN
# 46881676                     NaN                     NaN
#
#           rolling_mean_tmp_14_60
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 46881672                     NaN
# 46881673                     NaN
# 46881674                     NaN
# 46881675                     NaN
# 46881676                     NaN
#
# [46881677 rows x 40 columns]
