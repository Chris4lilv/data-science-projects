# %% [markdown]
# ## M5 Public LB
# The true labels of the public LB have been released as announced [here](https://www.kaggle.com/c/m5-forecasting-accuracy/discussion/155399).
#
# This gives us a unique opportunity of deeply exploring the additional data and understanding what went right and what went wrong. This could also help in improving and optimizing the model predictions for the final private test data.
#
# **P.S.** Don't forget to hover over the graphs to get point-specific details.

# %%
## importing packages
import numpy as np
import pandas as pd

from bokeh.layouts import column, row
from bokeh.models import Panel, Tabs, LinearAxis, Range1d, BoxAnnotation, LabelSet, Span
from bokeh.models.tools import HoverTool
from bokeh.palettes import Category20, Spectral3, Spectral4, Spectral8
from bokeh.plotting import ColumnDataSource, figure, output_notebook, show
from bokeh.transform import dodge

from math import pi
from typing import Union
from tqdm.notebook import tqdm

output_notebook()

LB_DATES = list(pd.date_range(start = "2016-04-25", end = "2016-05-22").strftime("%Y-%m-%d"))
LB_WEEKDAYS = pd.to_datetime(LB_DATES).to_series().dt.day_name()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Submission File
# For the purpose of this notebook, I will use the submission from [kneroma](https://www.kaggle.com/kneroma)'s kernel: https://www.kaggle.com/kneroma/m5-first-public-notebook-under-0-50 but feel free to replace this submission with your own submission files. All you need to do is replace *df_submission* before running the notebook.

# %%
sub_model2 = pd.read_csv('submission_to_0.47.csv')
sub_model3 = pd.read_csv('submission_to_0.47_param3.csv')
sub_model3_fe = pd.read_csv('submission_weighted_param_3_7_14_21_28.csv')

# %%
df_submission = pd.read_csv('submission_self_run.csv')
# eval_set = df_submission[30490:].copy()
# valid_set = df_submission[30490:].copy()
# valid_set["id"] = valid_set["id"].str.replace("evaluation$", "validation")
# df_submission = pd.concat([valid_set,eval_set],axis=0,ignore_index=True)

# %%
combined = pd.DataFrame()
combined['id'] = sub_model2['id']
cols = [f'F{i}'for i in range(1,29)]
for col in cols:
    combined[col] = (sub_model2[col] + sub_model3[col]) / 2
df_submission = combined
df_submission.head()
# Out:
#                             id        F1        F2        F3        F4  \
# 0  FOODS_1_001_CA_1_validation  0.820314  0.802266  0.800925  0.845782
# 1  FOODS_1_001_CA_2_validation  0.931526  0.929918  0.869254  1.141765
# 2  FOODS_1_001_CA_3_validation  1.059968  0.983349  0.839190  0.841920
# 3  FOODS_1_001_CA_4_validation  0.418446  0.370121  0.372825  0.380642
# 4  FOODS_1_001_TX_1_validation  0.209947  0.208023  0.212368  0.220885
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  1.028260  1.024485  1.082191  0.925428  0.869167  ...  1.041883  1.274529
# 1  1.269044  1.110007  1.296057  0.903790  0.956518  ...  1.260898  1.571852
# 2  0.942459  1.075376  1.107389  1.028322  1.089524  ...  0.998834  1.640254
# 3  0.452901  0.400971  0.469814  0.414770  0.410258  ...  0.463769  0.485351
# 4  0.207161  0.176158  0.209236  0.552172  0.481739  ...  0.428016  0.405850
#
#         F21       F22       F23       F24       F25       F26       F27  \
# 0  1.132313  0.907766  0.791097  0.787247  0.827984  1.000772  1.193520
# 1  1.519076  1.012010  1.013187  0.983792  1.053411  1.270174  1.610439
# 2  1.722733  1.026528  0.950526  0.840668  0.830471  0.929206  1.320485
# 3  0.449296  0.369747  0.352477  0.361242  0.380714  0.434519  0.449651
# 4  0.405092  0.281968  0.276604  0.293723  0.292655  0.335101  0.362760
#
#         F28
# 0  1.153473
# 1  1.402252
# 2  1.320658
# 3  0.464405
# 4  0.370952
#
# [5 rows x 29 columns]

# %%
df_submission.drop('Unnamed: 0',axis=1, inplace=True)

# %% [markdown]
# ## Evaluation
# Thanks to [sakami](https://www.kaggle.com/sakami) for providing a neat class for the evaluation metric [here](https://www.kaggle.com/c/m5-forecasting-accuracy/discussion/133834).
#
# You can find details on how to calculate your true public LB score and rank: https://www.kaggle.com/rohanrao/m5-how-to-get-your-public-lb-score-rank.

# %%
## evaluation metric
## edited from https://www.kaggle.com/c/m5-forecasting-accuracy/discussion/133834
class WRMSSEEvaluator(object):

    def __init__(self, train_df: pd.DataFrame, valid_df: pd.DataFrame, calendar: pd.DataFrame, prices: pd.DataFrame):
        train_y = train_df.loc[:, train_df.columns.str.startswith('d_')]
        train_target_columns = train_y.columns.tolist()
        weight_columns = train_y.iloc[:, -28:].columns.tolist()

        train_df['all_id'] = 0  # for lv1 aggregation

        id_columns = train_df.loc[:, ~train_df.columns.str.startswith('d_')].columns.tolist()
        valid_target_columns = valid_df.loc[:, valid_df.columns.str.startswith('d_')].columns.tolist()

        if not all([c in valid_df.columns for c in id_columns]):
            valid_df = pd.concat([train_df[id_columns], valid_df], axis=1, sort=False)

        self.train_df = train_df
        self.valid_df = valid_df
        self.calendar = calendar
        self.prices = prices

        self.weight_columns = weight_columns
        self.id_columns = id_columns
        self.valid_target_columns = valid_target_columns

        weight_df = self.get_weight_df()

        self.group_ids = (
            'all_id',
            'cat_id',
            'state_id',
            'dept_id',
            'store_id',
            'item_id',
            ['state_id', 'cat_id'],
            ['state_id', 'dept_id'],
            ['store_id', 'cat_id'],
            ['store_id', 'dept_id'],
            ['item_id', 'state_id'],
            ['item_id', 'store_id']
        )

        for i, group_id in enumerate(tqdm(self.group_ids)):
            train_y = train_df.groupby(group_id)[train_target_columns].sum()
            scale = []
            for _, row in train_y.iterrows():
                series = row.values[np.argmax(row.values != 0):]
                scale.append(((series[1:] - series[:-1]) ** 2).mean())
            setattr(self, f'lv{i + 1}_scale', np.array(scale))
            setattr(self, f'lv{i + 1}_train_df', train_y)
            setattr(self, f'lv{i + 1}_valid_df', valid_df.groupby(group_id)[valid_target_columns].sum())

            lv_weight = weight_df.groupby(group_id)[weight_columns].sum().sum(axis=1)
            setattr(self, f'lv{i + 1}_weight', lv_weight / lv_weight.sum())

    def get_weight_df(self) -> pd.DataFrame:
        day_to_week = self.calendar.set_index('d')['wm_yr_wk'].to_dict()
        weight_df = self.train_df[['item_id', 'store_id'] + self.weight_columns].set_index(['item_id', 'store_id'])
        weight_df = weight_df.stack().reset_index().rename(columns={'level_2': 'd', 0: 'value'})
        weight_df['wm_yr_wk'] = weight_df['d'].map(day_to_week)

        weight_df = weight_df.merge(self.prices, how='left', on=['item_id', 'store_id', 'wm_yr_wk'])
        weight_df['value'] = weight_df['value'] * weight_df['sell_price']
        weight_df = weight_df.set_index(['item_id', 'store_id', 'd']).unstack(level=2)['value']
        weight_df = weight_df.loc[zip(self.train_df.item_id, self.train_df.store_id), :].reset_index(drop=True)
        weight_df = pd.concat([self.train_df[self.id_columns], weight_df], axis=1, sort=False)
        return weight_df

    def rmsse(self, valid_preds: pd.DataFrame, lv: int) -> pd.Series:
        valid_y = getattr(self, f'lv{lv}_valid_df')
        score = ((valid_y - valid_preds) ** 2).mean(axis=1)
        scale = getattr(self, f'lv{lv}_scale')
        return (score / scale).map(np.sqrt)

    def score(self, valid_preds: Union[pd.DataFrame, np.ndarray]):
        assert self.valid_df[self.valid_target_columns].shape == valid_preds.shape

        if isinstance(valid_preds, np.ndarray):
            valid_preds = pd.DataFrame(valid_preds, columns=self.valid_target_columns)

        valid_preds = pd.concat([self.valid_df[self.id_columns], valid_preds], axis=1, sort=False)

        group_ids = []
        all_scores = []

        for i, group_id in enumerate(self.group_ids):
            lv_scores = self.rmsse(valid_preds.groupby(group_id)[self.valid_target_columns].sum(), i + 1)
            weight = getattr(self, f'lv{i + 1}_weight')
            lv_scores = pd.concat([weight, lv_scores], axis=1, sort=False).prod(axis=1)
            group_ids.append(group_id)
            all_scores.append(lv_scores.sum())

        return group_ids, all_scores
    
    def get_scores(self, valid_preds: Union[pd.DataFrame, np.ndarray], lv: int):
        assert self.valid_df[self.valid_target_columns].shape == valid_preds.shape

        if isinstance(valid_preds, np.ndarray):
            valid_preds = pd.DataFrame(valid_preds, columns=self.valid_target_columns)

        valid_preds = pd.concat([self.valid_df[self.id_columns], valid_preds], axis=1, sort=False)
        
        for i, group_id in enumerate(self.group_ids):
            if lv == i+1:
                valid_df = valid_preds.groupby(group_id)[self.valid_target_columns].sum()
                valid_y = getattr(self, f"lv{lv}_valid_df")
                scale = getattr(self, f"lv{lv}_scale")
                weight = getattr(self, f"lv{lv}_weight")
                valid_df["score"] = (((valid_y - valid_df) ** 2).mean(axis = 1) / scale).map(np.sqrt)
                valid_df.columns = ["pred_d_" + str(x) for x in range(1914, 1942)] + ["score"]
                valid_df = pd.concat([valid_df, valid_y], axis = 1)
                valid_df["score_weighted"] = valid_df.score * weight
                valid_df["score_percentage"] = valid_df.score_weighted / valid_df.score_weighted.sum()

        return valid_df.reset_index()

# %% [markdown]
# ## Preparing data
# Reading the datasets and preparing the evaluator class.

# %%
## reading data
df_train_full =  pd.read_csv("sales_train_evaluation/sales_train_evaluation.csv")
df_calendar = pd.read_csv("calendar.csv")
df_prices = pd.read_csv("sell_prices.csv")
df_sample_submission = pd.read_csv("sample_submission.csv")
df_sample_submission["order"] = range(df_sample_submission.shape[0])

df_train = df_train_full.iloc[:, :-28]
df_valid = df_train_full.iloc[:, -28:]

evaluator = WRMSSEEvaluator(df_train, df_valid, df_calendar, df_prices)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))

# %% [markdown]
# ## Public LB Verification
# Verifying the public LB calculation. This submission scores 0.48874 on the public LB and we should get the same score offline.

# %% [markdown]
# ### Dynamic params optimization

# %%
score_max = 1000
params = {'param1':-1,'param2':-1}

df1 = pd.read_csv('submission_witch_to_0.47_2.csv')
df2 = pd.read_csv('submission_witch_to_0.47_3.csv')

combined = pd.DataFrame()
combined['id'] = df1['id']
cols = [f'F{i}'for i in range(1,29)]
weights1 = [round(i,2) for i in np.arange(0.2,0.4,0.01)]
weights2 = [round(i,2) for i in np.arange(0.6,0.8,0.01)]

for weight1 in weights1:
    for weight2 in weights2:
        #Generate submission file
        for col in cols:
            combined[col] = (weight1*df1[col] + weight2*df2[col])
        #Evaluate its score
        ## evaluating submission from public kernel M5 First Public Notebook Under 0.50
        ## from https://www.kaggle.com/kneroma/m5-first-public-notebook-under-0-50
        preds_valid = combined[combined.id.str.contains("validation")]
        preds_valid = preds_valid.merge(df_sample_submission[["id", "order"]], on = "id").sort_values("order").drop(["id", "order"], axis = 1).reset_index(drop = True)
        preds_valid.rename(columns = {
            "F1": "d_1914", "F2": "d_1915", "F3": "d_1916", "F4": "d_1917", "F5": "d_1918", "F6": "d_1919", "F7": "d_1920",
            "F8": "d_1921", "F9": "d_1922", "F10": "d_1923", "F11": "d_1924", "F12": "d_1925", "F13": "d_1926", "F14": "d_1927",
            "F15": "d_1928", "F16": "d_1929", "F17": "d_1930", "F18": "d_1931", "F19": "d_1932", "F20": "d_1933", "F21": "d_1934",
            "F22": "d_1935", "F23": "d_1936", "F24": "d_1937", "F25": "d_1938", "F26": "d_1939", "F27": "d_1940", "F28": "d_1941"
        }, inplace = True)

        groups, scores = evaluator.score(preds_valid)

        score_public_lb = np.mean(scores)

        print(f"\nPublic LB Score: {round(score_public_lb, 5)}")
        if round(score_public_lb, 5) < score_max:
            score_max = round(score_public_lb, 5);
            params['param1'] = weight1
            params['param2'] = weight2
# Out:
# Score for group all_id: 1.53369
# Score for group cat_id: 1.47431
# Score for group state_id: 1.42485
# Score for group dept_id: 1.43936
# Score for group store_id: 1.37043
# Score for group item_id: 0.9352
# Score for group ['state_id', 'cat_id']: 1.3572
# Score for group ['state_id', 'dept_id']: 1.31312
# Score for group ['store_id', 'cat_id']: 1.26908
# Score for group ['store_id', 'dept_id']: 1.20055
# Score for group ['item_id', 'state_id']: 0.88088
# Score for group ['item_id', 'store_id']: 0.84304
#
# Public LB Score: 1.25348
# Score for group all_id: 1.45947
# Score for group cat_id: 1.40336
# Score for group state_id: 1.3578
# Score for group dept_id: 1.37081
# Score for group store_id: 1.30779
# Score for group item_id: 0.9217
# Score for group ['state_id', 'cat_id']: 1.2949
# Score for group ['state_id', 'dept_id']: 1.25445
# Score for group ['store_id', 'cat_id']: 1.21399
# Score for group ['store_id', 'dept_id']: 1.15152
# Score for group ['item_id', 'state_id']: 0.87393
# Score for group ['item_id', 'store_id']: 0.84026
#
# Public LB Score: 1.20416
# Score for group all_id: 1.38531
# Score for group cat_id: 1.33251
# Score for group state_id: 1.2909
# Score for group dept_id: 1.30244
# Score for group store_id: 1.24539
# Score for group item_id: 0.90881
# Score for group ['state_id', 'cat_id']: 1.23284
# Score for group ['state_id', 'dept_id']: 1.19611
# Score for group ['store_id', 'cat_id']: 1.15926
# Score for group ['store_id', 'dept_id']: 1.10301
# Score for group ['item_id', 'state_id']: 0.86733
# Score for group ['item_id', 'store_id']: 0.83766
#
# Public LB Score: 1.15513
# Score for group all_id: 1.31122
# Score for group cat_id: 1.26178
# Score for group state_id: 1.22418
# Score for group dept_id: 1.23427
# Score for group store_id: 1.18326
# Score for group item_id: 0.89654
# Score for group ['state_id', 'cat_id']: 1.17105
# Score for group ['state_id', 'dept_id']: 1.13818
# Score for group ['store_id', 'cat_id']: 1.10494
# Score for group ['store_id', 'dept_id']: 1.05511
# Score for group ['item_id', 'state_id']: 0.86109
# Score for group ['item_id', 'store_id']: 0.83524
#
# Public LB Score: 1.10641
# Score for group all_id: 1.23722
# Score for group cat_id: 1.1912
# Score for group state_id: 1.15766
# Score for group dept_id: 1.16635
# Score for group store_id: 1.12146
# Score for group item_id: 0.88494
# Score for group ['state_id', 'cat_id']: 1.10958
# Score for group ['state_id', 'dept_id']: 1.08071
# Score for group ['store_id', 'cat_id']: 1.05111
# Score for group ['store_id', 'dept_id']: 1.00791
# Score for group ['item_id', 'state_id']: 0.85522
# Score for group ['item_id', 'store_id']: 0.83299
#
# Public LB Score: 1.05803
# Score for group all_id: 1.16332
# Score for group cat_id: 1.12079
# Score for group state_id: 1.09139
# Score for group dept_id: 1.09871
# Score for group store_id: 1.06004
# Score for group item_id: 0.87402
# Score for group ['state_id', 'cat_id']: 1.04847
# Score for group ['state_id', 'dept_id']: 1.02378
# Score for group ['store_id', 'cat_id']: 0.99783
# Score for group ['store_id', 'dept_id']: 0.96153
# Score for group ['item_id', 'state_id']: 0.84973
# Score for group ['item_id', 'store_id']: 0.83092
#
# Public LB Score: 1.01005
# Score for group all_id: 1.08954
# Score for group cat_id: 1.05058
# Score for group state_id: 1.02541
# Score for group dept_id: 1.03143
# Score for group store_id: 0.99908
# Score for group item_id: 0.86382
# Score for group ['state_id', 'cat_id']: 0.98781
# Score for group ['state_id', 'dept_id']: 0.9675
# Score for group ['store_id', 'cat_id']: 0.94523
# Score for group ['store_id', 'dept_id']: 0.9161
# Score for group ['item_id', 'state_id']: 0.84463
# Score for group ['item_id', 'store_id']: 0.82903
#
# Public LB Score: 0.96251
# Score for group all_id: 1.01591
# Score for group cat_id: 0.98062
# Score for group state_id: 0.95978
# Score for group dept_id: 0.96457
# Score for group store_id: 0.93867
# Score for group item_id: 0.85436
# Score for group ['state_id', 'cat_id']: 0.92766
# Score for group ['state_id', 'dept_id']: 0.91199
# Score for group ['store_id', 'cat_id']: 0.8934
# Score for group ['store_id', 'dept_id']: 0.87181
# Score for group ['item_id', 'state_id']: 0.83992
# Score for group ['item_id', 'store_id']: 0.82733
#
# Public LB Score: 0.9155
# Score for group all_id: 0.94246
# Score for group cat_id: 0.91097
# Score for group state_id: 0.89458
# Score for group dept_id: 0.89825
# Score for group store_id: 0.87893
# Score for group item_id: 0.84567
# Score for group ['state_id', 'cat_id']: 0.86813
# Score for group ['state_id', 'dept_id']: 0.8574
# Score for group ['store_id', 'cat_id']: 0.84251
# Score for group ['store_id', 'dept_id']: 0.82886
# Score for group ['item_id', 'state_id']: 0.83562
# Score for group ['item_id', 'store_id']: 0.82582
#
# Public LB Score: 0.8691
# Score for group all_id: 0.86924
# Score for group cat_id: 0.84171
# Score for group state_id: 0.82989
# Score for group dept_id: 0.83259
# Score for group store_id: 0.82001
# Score for group item_id: 0.83777
# Score for group ['state_id', 'cat_id']: 0.80937
# Score for group ['state_id', 'dept_id']: 0.80391
# Score for group ['store_id', 'cat_id']: 0.79275
# Score for group ['store_id', 'dept_id']: 0.78751
# Score for group ['item_id', 'state_id']: 0.83173
# Score for group ['item_id', 'store_id']: 0.82449
#
# Public LB Score: 0.82341
# Score for group all_id: 0.79631
# Score for group cat_id: 0.77294
# Score for group state_id: 0.76586
# Score for group dept_id: 0.7678
# Score for group store_id: 0.76212
# Score for group item_id: 0.83069
# Score for group ['state_id', 'cat_id']: 0.75153
# Score for group ['state_id', 'dept_id']: 0.75177
# Score for group ['store_id', 'cat_id']: 0.74437
# Score for group ['store_id', 'dept_id']: 0.7481
# Score for group ['item_id', 'state_id']: 0.82826
# Score for group ['item_id', 'store_id']: 0.82335
#
# Public LB Score: 0.77859
# Score for group all_id: 0.72376
# Score for group cat_id: 0.7048
# Score for group state_id: 0.70264
# Score for group dept_id: 0.70413
# Score for group store_id: 0.70554
# Score for group item_id: 0.82444
# Score for group ['state_id', 'cat_id']: 0.69485
# Score for group ['state_id', 'dept_id']: 0.70128
# Score for group ['store_id', 'cat_id']: 0.69769
# Score for group ['store_id', 'dept_id']: 0.71103
# Score for group ['item_id', 'state_id']: 0.82523
# Score for group ['item_id', 'store_id']: 0.8224
#
# Public LB Score: 0.73481
# Score for group all_id: 0.65171
# Score for group cat_id: 0.63751
# Score for group state_id: 0.64048
# Score for group dept_id: 0.64195
# Score for group store_id: 0.65064
# Score for group item_id: 0.81904
# Score for group ['state_id', 'cat_id']: 0.63961
# Score for group ['state_id', 'dept_id']: 0.65281
# Score for group ['store_id', 'cat_id']: 0.65313
# Score for group ['store_id', 'dept_id']: 0.67675
# Score for group ['item_id', 'state_id']: 0.82262
# Score for group ['item_id', 'store_id']: 0.82164
#
# Public LB Score: 0.69232
# Score for group all_id: 0.58036
# Score for group cat_id: 0.57138
# Score for group state_id: 0.57969
# Score for group dept_id: 0.5818
# Score for group store_id: 0.59796
# Score for group item_id: 0.8145
# Score for group ['state_id', 'cat_id']: 0.58623
# Score for group ['state_id', 'dept_id']: 0.60689
# Score for group ['store_id', 'cat_id']: 0.61121
# Score for group ['store_id', 'dept_id']: 0.64575
# Score for group ['item_id', 'state_id']: 0.82046
# Score for group ['item_id', 'store_id']: 0.82108
#
# Public LB Score: 0.65144
# Score for group all_id: 0.51
# Score for group cat_id: 0.50686
# Score for group state_id: 0.52075
# Score for group dept_id: 0.52447
# Score for group store_id: 0.54823
# Score for group item_id: 0.81085
# Score for group ['state_id', 'cat_id']: 0.53525
# Score for group ['state_id', 'dept_id']: 0.56418
# Score for group ['store_id', 'cat_id']: 0.57258
# Score for group ['store_id', 'dept_id']: 0.61849
# Score for group ['item_id', 'state_id']: 0.81874
# Score for group ['item_id', 'store_id']: 0.82071
#
# Public LB Score: 0.61259
# Score for group all_id: 0.4411
# Score for group cat_id: 0.44469
# Score for group state_id: 0.46435
# Score for group dept_id: 0.47112
# Score for group store_id: 0.50248
# Score for group item_id: 0.80808
# Score for group ['state_id', 'cat_id']: 0.48741
# Score for group ['state_id', 'dept_id']: 0.52563
# Score for group ['store_id', 'cat_id']: 0.53797
# Score for group ['store_id', 'dept_id']: 0.59534
# Score for group ['item_id', 'state_id']: 0.81746
# Score for group ['item_id', 'store_id']: 0.82053
#
# Public LB Score: 0.57635
# Score for group all_id: 0.37446
# Score for group cat_id: 0.38599
# Score for group state_id: 0.41153
# Score for group dept_id: 0.42342
# Score for group store_id: 0.46201
# Score for group item_id: 0.8062
# Score for group ['state_id', 'cat_id']: 0.44378
# Score for group ['state_id', 'dept_id']: 0.4925
# Score for group ['store_id', 'cat_id']: 0.50816
# Score for group ['store_id', 'dept_id']: 0.57658
# Score for group ['item_id', 'state_id']: 0.81664
# Score for group ['item_id', 'store_id']: 0.82054
#
# Public LB Score: 0.54348
# Score for group all_id: 0.31154
# Score for group cat_id: 0.33259
# Score for group state_id: 0.36389
# Score for group dept_id: 0.38367
# Score for group store_id: 0.4283
# Score for group item_id: 0.80521
# Score for group ['state_id', 'cat_id']: 0.40581
# Score for group ['state_id', 'dept_id']: 0.46634
# Score for group ['store_id', 'cat_id']: 0.48387
# Score for group ['store_id', 'dept_id']: 0.5624
# Score for group ['item_id', 'state_id']: 0.81626
# Score for group ['item_id', 'store_id']: 0.82074
#
# Public LB Score: 0.51505
# Score for group all_id: 0.25512
# Score for group cat_id: 0.28722
# Score for group state_id: 0.32398
# Score for group dept_id: 0.35486
# Score for group store_id: 0.40276
# Score for group item_id: 0.80511
# Score for group ['state_id', 'cat_id']: 0.37542
# Score for group ['state_id', 'dept_id']: 0.44873
# Score for group ['store_id', 'cat_id']: 0.46568
# Score for group ['store_id', 'dept_id']: 0.55298
# Score for group ['item_id', 'state_id']: 0.81633
# Score for group ['item_id', 'store_id']: 0.82114
#
# Public LB Score: 0.49245
# Score for group all_id: 0.21048
# Score for group cat_id: 0.25364
# Score for group state_id: 0.29546
# Score for group dept_id: 0.34035
# Score for group store_id: 0.38653
# Score for group item_id: 0.80589
# Score for group ['state_id', 'cat_id']: 0.35486
# Score for group ['state_id', 'dept_id']: 0.44067
# Score for group ['store_id', 'cat_id']: 0.45406
# Score for group ['store_id', 'dept_id']: 0.54847
# Score for group ['item_id', 'state_id']: 0.81685
# Score for group ['item_id', 'store_id']: 0.82173
#
# Public LB Score: 0.47742
# Score for group all_id: 0.18628
# Score for group cat_id: 0.23641
# Score for group state_id: 0.28249
# Score for group dept_id: 0.34266
# Score for group store_id: 0.38028
# Score for group item_id: 0.80753
# Score for group ['state_id', 'cat_id']: 0.34615
# Score for group ['state_id', 'dept_id']: 0.44221
# Score for group ['store_id', 'cat_id']: 0.44935
# Score for group ['store_id', 'dept_id']: 0.54894
# Score for group ['item_id', 'state_id']: 0.81781
# Score for group ['item_id', 'store_id']: 0.82251
#
# Public LB Score: 0.47189
# Score for group all_id: 1.45945
# Score for group cat_id: 1.40327
# Score for group state_id: 1.35781
# Score for group dept_id: 1.37073
# Score for group store_id: 1.30781
# Score for group item_id: 0.92161
# Score for group ['state_id', 'cat_id']: 1.29487
# Score for group ['state_id', 'dept_id']: 1.25439
# Score for group ['store_id', 'cat_id']: 1.21397
# Score for group ['store_id', 'dept_id']: 1.15147
# Score for group ['item_id', 'state_id']: 0.87387
# Score for group ['item_id', 'store_id']: 0.84024
#
# Public LB Score: 1.20412
# Score for group all_id: 1.38529
# Score for group cat_id: 1.33241
# Score for group state_id: 1.29091
# Score for group dept_id: 1.30235
# Score for group store_id: 1.24541
# Score for group item_id: 0.90871
# Score for group ['state_id', 'cat_id']: 1.2328
# Score for group ['state_id', 'dept_id']: 1.19606
# Score for group ['store_id', 'cat_id']: 1.15924
# Score for group ['store_id', 'dept_id']: 1.10296
# Score for group ['item_id', 'state_id']: 0.86727
# Score for group ['item_id', 'store_id']: 0.83764
#
# Public LB Score: 1.15509
# Score for group all_id: 1.3112
# Score for group cat_id: 1.26169
# Score for group state_id: 1.22419
# Score for group dept_id: 1.23418
# Score for group store_id: 1.18328
# Score for group item_id: 0.89645
# Score for group ['state_id', 'cat_id']: 1.17101
# Score for group ['state_id', 'dept_id']: 1.13812
# Score for group ['store_id', 'cat_id']: 1.10492
# Score for group ['store_id', 'dept_id']: 1.05505
# Score for group ['item_id', 'state_id']: 0.86103
# Score for group ['item_id', 'store_id']: 0.83522
#
# Public LB Score: 1.10636
# Score for group all_id: 1.2372
# Score for group cat_id: 1.1911
# Score for group state_id: 1.15767
# Score for group dept_id: 1.16625
# Score for group store_id: 1.12148
# Score for group item_id: 0.88484
# Score for group ['state_id', 'cat_id']: 1.10954
# Score for group ['state_id', 'dept_id']: 1.08065
# Score for group ['store_id', 'cat_id']: 1.05108
# Score for group ['store_id', 'dept_id']: 1.00785
# Score for group ['item_id', 'state_id']: 0.85516
# Score for group ['item_id', 'store_id']: 0.83297
#
# Public LB Score: 1.05798
# Score for group all_id: 1.16329
# Score for group cat_id: 1.12068
# Score for group state_id: 1.0914
# Score for group dept_id: 1.09861
# Score for group store_id: 1.06006
# Score for group item_id: 0.87393
# Score for group ['state_id', 'cat_id']: 1.04843
# Score for group ['state_id', 'dept_id']: 1.02372
# Score for group ['store_id', 'cat_id']: 0.99781
# Score for group ['store_id', 'dept_id']: 0.96147
# Score for group ['item_id', 'state_id']: 0.84967
# Score for group ['item_id', 'store_id']: 0.8309
#
# Public LB Score: 1.01
# Score for group all_id: 1.08951
# Score for group cat_id: 1.05047
# Score for group state_id: 1.02542
# Score for group dept_id: 1.03132
# Score for group store_id: 0.99909
# Score for group item_id: 0.86373
# Score for group ['state_id', 'cat_id']: 0.98776
# Score for group ['state_id', 'dept_id']: 0.96743
# Score for group ['store_id', 'cat_id']: 0.9452
# Score for group ['store_id', 'dept_id']: 0.91605
# Score for group ['item_id', 'state_id']: 0.84457
# Score for group ['item_id', 'store_id']: 0.82901
#
# Public LB Score: 0.96246
# Score for group all_id: 1.01587
# Score for group cat_id: 0.98051
# Score for group state_id: 0.95978
# Score for group dept_id: 0.96446
# Score for group store_id: 0.93868
# Score for group item_id: 0.85427
# Score for group ['state_id', 'cat_id']: 0.92761
# Score for group ['state_id', 'dept_id']: 0.91191
# Score for group ['store_id', 'cat_id']: 0.89337
# Score for group ['store_id', 'dept_id']: 0.87175
# Score for group ['item_id', 'state_id']: 0.83986
# Score for group ['item_id', 'store_id']: 0.82731
#
# Public LB Score: 0.91545
# Score for group all_id: 0.94242
# Score for group cat_id: 0.91086
# Score for group state_id: 0.89457
# Score for group dept_id: 0.89812
# Score for group store_id: 0.87894
# Score for group item_id: 0.84558
# Score for group ['state_id', 'cat_id']: 0.86808
# Score for group ['state_id', 'dept_id']: 0.85731
# Score for group ['store_id', 'cat_id']: 0.84248
# Score for group ['store_id', 'dept_id']: 0.8288
# Score for group ['item_id', 'state_id']: 0.83556
# Score for group ['item_id', 'store_id']: 0.8258
#
# Public LB Score: 0.86904
# Score for group all_id: 0.86919
# Score for group cat_id: 0.84159
# Score for group state_id: 0.82989
# Score for group dept_id: 0.83246
# Score for group store_id: 0.82002
# Score for group item_id: 0.83768
# Score for group ['state_id', 'cat_id']: 0.80931
# Score for group ['state_id', 'dept_id']: 0.80382
# Score for group ['store_id', 'cat_id']: 0.79272
# Score for group ['store_id', 'dept_id']: 0.78746
# Score for group ['item_id', 'state_id']: 0.83167
# Score for group ['item_id', 'store_id']: 0.82447
#
# Public LB Score: 0.82336
# Score for group all_id: 0.79625
# Score for group cat_id: 0.77281
# Score for group state_id: 0.76584
# Score for group dept_id: 0.76766
# Score for group store_id: 0.76212
# Score for group item_id: 0.83059
# Score for group ['state_id', 'cat_id']: 0.75147
# Score for group ['state_id', 'dept_id']: 0.75167
# Score for group ['store_id', 'cat_id']: 0.74435
# Score for group ['store_id', 'dept_id']: 0.74805
# Score for group ['item_id', 'state_id']: 0.8282
# Score for group ['item_id', 'store_id']: 0.82333
#
# Public LB Score: 0.77853
# Score for group all_id: 0.72369
# Score for group cat_id: 0.70467
# Score for group state_id: 0.70262
# Score for group dept_id: 0.70398
# Score for group store_id: 0.70554
# Score for group item_id: 0.82434
# Score for group ['state_id', 'cat_id']: 0.69479
# Score for group ['state_id', 'dept_id']: 0.70117
# Score for group ['store_id', 'cat_id']: 0.69767
# Score for group ['store_id', 'dept_id']: 0.71098
# Score for group ['item_id', 'state_id']: 0.82516
# Score for group ['item_id', 'store_id']: 0.82238
#
# Public LB Score: 0.73475
# Score for group all_id: 0.65163
# Score for group cat_id: 0.63738
# Score for group state_id: 0.64045
# Score for group dept_id: 0.64178
# Score for group store_id: 0.65064
# Score for group item_id: 0.81894
# Score for group ['state_id', 'cat_id']: 0.63955
# Score for group ['state_id', 'dept_id']: 0.6527
# Score for group ['store_id', 'cat_id']: 0.65311
# Score for group ['store_id', 'dept_id']: 0.67671
# Score for group ['item_id', 'state_id']: 0.82256
# Score for group ['item_id', 'store_id']: 0.82162
#
# Public LB Score: 0.69226
# Score for group all_id: 0.58027
# Score for group cat_id: 0.57124
# Score for group state_id: 0.57965
# Score for group dept_id: 0.58162
# Score for group store_id: 0.59796
# Score for group item_id: 0.8144
# Score for group ['state_id', 'cat_id']: 0.58617
# Score for group ['state_id', 'dept_id']: 0.60677
# Score for group ['store_id', 'cat_id']: 0.6112
# Score for group ['store_id', 'dept_id']: 0.64573
# Score for group ['item_id', 'state_id']: 0.8204
# Score for group ['item_id', 'store_id']: 0.82106
#
# Public LB Score: 0.65137
# Score for group all_id: 0.50989
# Score for group cat_id: 0.50672
# Score for group state_id: 0.5207
# Score for group dept_id: 0.52428
# Score for group store_id: 0.54823
# Score for group item_id: 0.81075
# Score for group ['state_id', 'cat_id']: 0.53518
# Score for group ['state_id', 'dept_id']: 0.56405
# Score for group ['store_id', 'cat_id']: 0.57258
# Score for group ['store_id', 'dept_id']: 0.61849
# Score for group ['item_id', 'state_id']: 0.81868
# Score for group ['item_id', 'store_id']: 0.82069
#
# Public LB Score: 0.61252
# Score for group all_id: 0.44096
# Score for group cat_id: 0.44453
# Score for group state_id: 0.46428
# Score for group dept_id: 0.47091
# Score for group store_id: 0.50249
# Score for group item_id: 0.80798
# Score for group ['state_id', 'cat_id']: 0.48734
# Score for group ['state_id', 'dept_id']: 0.5255
# Score for group ['store_id', 'cat_id']: 0.53799
# Score for group ['store_id', 'dept_id']: 0.59535
# Score for group ['item_id', 'state_id']: 0.8174
# Score for group ['item_id', 'store_id']: 0.82051
#
# Public LB Score: 0.57627
# Score for group all_id: 0.3743
# Score for group cat_id: 0.38583
# Score for group state_id: 0.41144
# Score for group dept_id: 0.4232
# Score for group store_id: 0.46203
# Score for group item_id: 0.8061
# Score for group ['state_id', 'cat_id']: 0.4437
# Score for group ['state_id', 'dept_id']: 0.49237
# Score for group ['store_id', 'cat_id']: 0.5082
# Score for group ['store_id', 'dept_id']: 0.5766
# Score for group ['item_id', 'state_id']: 0.81658
# Score for group ['item_id', 'store_id']: 0.82052
#
# Public LB Score: 0.54341
# Score for group all_id: 0.31134
# Score for group cat_id: 0.33243
# Score for group state_id: 0.36378
# Score for group dept_id: 0.38346
# Score for group store_id: 0.42832
# Score for group item_id: 0.80512
# Score for group ['state_id', 'cat_id']: 0.40572
# Score for group ['state_id', 'dept_id']: 0.46623
# Score for group ['store_id', 'cat_id']: 0.48393
# Score for group ['store_id', 'dept_id']: 0.56243
# Score for group ['item_id', 'state_id']: 0.8162
# Score for group ['item_id', 'store_id']: 0.82073
#
# Public LB Score: 0.51497
# Score for group all_id: 0.25486
# Score for group cat_id: 0.28707
# Score for group state_id: 0.32383
# Score for group dept_id: 0.35465
# Score for group store_id: 0.40279
# Score for group item_id: 0.80502
# Score for group ['state_id', 'cat_id']: 0.37533
# Score for group ['state_id', 'dept_id']: 0.44864
# Score for group ['store_id', 'cat_id']: 0.46575
# Score for group ['store_id', 'dept_id']: 0.55302
# Score for group ['item_id', 'state_id']: 0.81628
# Score for group ['item_id', 'store_id']: 0.82112
#
# Public LB Score: 0.49236
# Score for group all_id: 0.21015
# Score for group cat_id: 0.25349
# Score for group state_id: 0.29527
# Score for group dept_id: 0.34017
# Score for group store_id: 0.38656
# Score for group item_id: 0.8058
# Score for group ['state_id', 'cat_id']: 0.35478
# Score for group ['state_id', 'dept_id']: 0.44059
# Score for group ['store_id', 'cat_id']: 0.45413
# Score for group ['store_id', 'dept_id']: 0.5485
# Score for group ['item_id', 'state_id']: 0.81679
# Score for group ['item_id', 'store_id']: 0.82171
#
# Public LB Score: 0.47733
# Score for group all_id: 0.1859
# Score for group cat_id: 0.23625
# Score for group state_id: 0.28227
# Score for group dept_id: 0.34253
# Score for group store_id: 0.38029
# Score for group item_id: 0.80745
# Score for group ['state_id', 'cat_id']: 0.34606
# Score for group ['state_id', 'dept_id']: 0.44215
# Score for group ['store_id', 'cat_id']: 0.44942
# Score for group ['store_id', 'dept_id']: 0.54897
# Score for group ['item_id', 'state_id']: 0.81776
# Score for group ['item_id', 'store_id']: 0.82249
#
# Public LB Score: 0.47179
# Score for group all_id: 0.19011
# Score for group cat_id: 0.23968
# Score for group state_id: 0.28692
# Score for group dept_id: 0.36097
# Score for group store_id: 0.38401
# Score for group item_id: 0.80994
# Score for group ['state_id', 'cat_id']: 0.35004
# Score for group ['state_id', 'dept_id']: 0.45264
# Score for group ['store_id', 'cat_id']: 0.45179
# Score for group ['store_id', 'dept_id']: 0.55444
# Score for group ['item_id', 'state_id']: 0.81916
# Score for group ['item_id', 'store_id']: 0.82345
#
# Public LB Score: 0.47693
# Score for group all_id: 1.38528
# Score for group cat_id: 1.33232
# Score for group state_id: 1.29093
# Score for group dept_id: 1.30226
# Score for group store_id: 1.24543
# Score for group item_id: 0.90862
# Score for group ['state_id', 'cat_id']: 1.23276
# Score for group ['state_id', 'dept_id']: 1.196
# Score for group ['store_id', 'cat_id']: 1.15922
# Score for group ['store_id', 'dept_id']: 1.10291
# Score for group ['item_id', 'state_id']: 0.86721
# Score for group ['item_id', 'store_id']: 0.83762
#
# Public LB Score: 1.15505
# Score for group all_id: 1.31119
# Score for group cat_id: 1.26159
# Score for group state_id: 1.2242
# Score for group dept_id: 1.23409
# Score for group store_id: 1.1833
# Score for group item_id: 0.89636
# Score for group ['state_id', 'cat_id']: 1.17097
# Score for group ['state_id', 'dept_id']: 1.13806
# Score for group ['store_id', 'cat_id']: 1.1049
# Score for group ['store_id', 'dept_id']: 1.055
# Score for group ['item_id', 'state_id']: 0.86098
# Score for group ['item_id', 'store_id']: 0.8352
#
# Public LB Score: 1.10632
# Score for group all_id: 1.23718
# Score for group cat_id: 1.191
# Score for group state_id: 1.15768
# Score for group dept_id: 1.16615
# Score for group store_id: 1.1215
# Score for group item_id: 0.88475
# Score for group ['state_id', 'cat_id']: 1.10949
# Score for group ['state_id', 'dept_id']: 1.08058
# Score for group ['store_id', 'cat_id']: 1.05106
# Score for group ['store_id', 'dept_id']: 1.0078
# Score for group ['item_id', 'state_id']: 0.85511
# Score for group ['item_id', 'store_id']: 0.83295
#
# Public LB Score: 1.05794
# Score for group all_id: 1.16327
# Score for group cat_id: 1.12058
# Score for group state_id: 1.09141
# Score for group dept_id: 1.09851
# Score for group store_id: 1.06008
# Score for group item_id: 0.87384
# Score for group ['state_id', 'cat_id']: 1.04839
# Score for group ['state_id', 'dept_id']: 1.02365
# Score for group ['store_id', 'cat_id']: 0.99779
# Score for group ['store_id', 'dept_id']: 0.96142
# Score for group ['item_id', 'state_id']: 0.84961
# Score for group ['item_id', 'store_id']: 0.83088
#
# Public LB Score: 1.00995
# Score for group all_id: 1.08948
# Score for group cat_id: 1.05037
# Score for group state_id: 1.02542
# Score for group dept_id: 1.03121
# Score for group store_id: 0.99911
# Score for group item_id: 0.86363
# Score for group ['state_id', 'cat_id']: 0.98772
# Score for group ['state_id', 'dept_id']: 0.96736
# Score for group ['store_id', 'cat_id']: 0.94518
# Score for group ['store_id', 'dept_id']: 0.91599
# Score for group ['item_id', 'state_id']: 0.84451
# Score for group ['item_id', 'store_id']: 0.829
#
# Public LB Score: 0.96241
# Score for group all_id: 1.01584
# Score for group cat_id: 0.9804
# Score for group state_id: 0.95978
# Score for group dept_id: 0.96434
# Score for group store_id: 0.93869
# Score for group item_id: 0.85418
# Score for group ['state_id', 'cat_id']: 0.92756
# Score for group ['state_id', 'dept_id']: 0.91184
# Score for group ['store_id', 'cat_id']: 0.89335
# Score for group ['store_id', 'dept_id']: 0.8717
# Score for group ['item_id', 'state_id']: 0.8398
# Score for group ['item_id', 'store_id']: 0.82729
#
# Public LB Score: 0.9154
# Score for group all_id: 0.94238
# Score for group cat_id: 0.91075
# Score for group state_id: 0.89457
# Score for group dept_id: 0.89801
# Score for group store_id: 0.87895
# Score for group item_id: 0.84548
# Score for group ['state_id', 'cat_id']: 0.86803
# Score for group ['state_id', 'dept_id']: 0.85723
# Score for group ['store_id', 'cat_id']: 0.84246
# Score for group ['store_id', 'dept_id']: 0.82874
# Score for group ['item_id', 'state_id']: 0.8355
# Score for group ['item_id', 'store_id']: 0.82578
#
# Public LB Score: 0.86899
# Score for group all_id: 0.86914
# Score for group cat_id: 0.84147
# Score for group state_id: 0.82988
# Score for group dept_id: 0.83234
# Score for group store_id: 0.82002
# Score for group item_id: 0.83758
# Score for group ['state_id', 'cat_id']: 0.80926
# Score for group ['state_id', 'dept_id']: 0.80373
# Score for group ['store_id', 'cat_id']: 0.7927
# Score for group ['store_id', 'dept_id']: 0.7874
# Score for group ['item_id', 'state_id']: 0.83161
# Score for group ['item_id', 'store_id']: 0.82445
#
# Public LB Score: 0.8233
# Score for group all_id: 0.7962
# Score for group cat_id: 0.77269
# Score for group state_id: 0.76583
# Score for group dept_id: 0.76752
# Score for group store_id: 0.76213
# Score for group item_id: 0.8305
# Score for group ['state_id', 'cat_id']: 0.75142
# Score for group ['state_id', 'dept_id']: 0.75158
# Score for group ['store_id', 'cat_id']: 0.74433
# Score for group ['store_id', 'dept_id']: 0.748
# Score for group ['item_id', 'state_id']: 0.82814
# Score for group ['item_id', 'store_id']: 0.82331
#
# Public LB Score: 0.77847
# Score for group all_id: 0.72363
# Score for group cat_id: 0.70455
# Score for group state_id: 0.7026
# Score for group dept_id: 0.70383
# Score for group store_id: 0.70554
# Score for group item_id: 0.82424
# Score for group ['state_id', 'cat_id']: 0.69473
# Score for group ['state_id', 'dept_id']: 0.70107
# Score for group ['store_id', 'cat_id']: 0.69765
# Score for group ['store_id', 'dept_id']: 0.71094
# Score for group ['item_id', 'state_id']: 0.82511
# Score for group ['item_id', 'store_id']: 0.82236
#
# Public LB Score: 0.73469
# Score for group all_id: 0.65156
# Score for group cat_id: 0.63725
# Score for group state_id: 0.64042
# Score for group dept_id: 0.64162
# Score for group store_id: 0.65064
# Score for group item_id: 0.81884
# Score for group ['state_id', 'cat_id']: 0.63949
# Score for group ['state_id', 'dept_id']: 0.65259
# Score for group ['store_id', 'cat_id']: 0.6531
# Score for group ['store_id', 'dept_id']: 0.67668
# Score for group ['item_id', 'state_id']: 0.8225
# Score for group ['item_id', 'store_id']: 0.82161
#
# Public LB Score: 0.69219
# Score for group all_id: 0.58018
# Score for group cat_id: 0.5711
# Score for group state_id: 0.57962
# Score for group dept_id: 0.58145
# Score for group store_id: 0.59796
# Score for group item_id: 0.81431
# Score for group ['state_id', 'cat_id']: 0.5861
# Score for group ['state_id', 'dept_id']: 0.60665
# Score for group ['store_id', 'cat_id']: 0.6112
# Score for group ['store_id', 'dept_id']: 0.64572
# Score for group ['item_id', 'state_id']: 0.82034
# Score for group ['item_id', 'store_id']: 0.82104
#
# Public LB Score: 0.65131
# Score for group all_id: 0.50979
# Score for group cat_id: 0.50657
# Score for group state_id: 0.52065
# Score for group dept_id: 0.52409
# Score for group store_id: 0.54824
# Score for group item_id: 0.81065
# Score for group ['state_id', 'cat_id']: 0.53511
# Score for group ['state_id', 'dept_id']: 0.56393
# Score for group ['store_id', 'cat_id']: 0.57259
# Score for group ['store_id', 'dept_id']: 0.61849
# Score for group ['item_id', 'state_id']: 0.81862
# Score for group ['item_id', 'store_id']: 0.82067
#
# Public LB Score: 0.61245
# Score for group all_id: 0.44084
# Score for group cat_id: 0.44438
# Score for group state_id: 0.46422
# Score for group dept_id: 0.47071
# Score for group store_id: 0.5025
# Score for group item_id: 0.80788
# Score for group ['state_id', 'cat_id']: 0.48727
# Score for group ['state_id', 'dept_id']: 0.52538
# Score for group ['store_id', 'cat_id']: 0.53802
# Score for group ['store_id', 'dept_id']: 0.59537
# Score for group ['item_id', 'state_id']: 0.81735
# Score for group ['item_id', 'store_id']: 0.82049
#
# Public LB Score: 0.5762
# Score for group all_id: 0.37414
# Score for group cat_id: 0.38568
# Score for group state_id: 0.41135
# Score for group dept_id: 0.42299
# Score for group store_id: 0.46205
# Score for group item_id: 0.80601
# Score for group ['state_id', 'cat_id']: 0.44363
# Score for group ['state_id', 'dept_id']: 0.49225
# Score for group ['store_id', 'cat_id']: 0.50825
# Score for group ['store_id', 'dept_id']: 0.57662
# Score for group ['item_id', 'state_id']: 0.81652
# Score for group ['item_id', 'store_id']: 0.8205
#
# Public LB Score: 0.54333
# Score for group all_id: 0.31114
# Score for group cat_id: 0.33228
# Score for group state_id: 0.36366
# Score for group dept_id: 0.38325
# Score for group store_id: 0.42836
# Score for group item_id: 0.80502
# Score for group ['state_id', 'cat_id']: 0.40565
# Score for group ['state_id', 'dept_id']: 0.46612
# Score for group ['store_id', 'cat_id']: 0.48399
# Score for group ['store_id', 'dept_id']: 0.56246
# Score for group ['item_id', 'state_id']: 0.81615
# Score for group ['item_id', 'store_id']: 0.82071
#
# Public LB Score: 0.5149
# Score for group all_id: 0.25461
# Score for group cat_id: 0.28693
# Score for group state_id: 0.32368
# Score for group dept_id: 0.35446
# Score for group store_id: 0.40283
# Score for group item_id: 0.80493
# Score for group ['state_id', 'cat_id']: 0.37526
# Score for group ['state_id', 'dept_id']: 0.44855
# Score for group ['store_id', 'cat_id']: 0.46583
# Score for group ['store_id', 'dept_id']: 0.55306
# Score for group ['item_id', 'state_id']: 0.81622
# Score for group ['item_id', 'store_id']: 0.82111
#
# Public LB Score: 0.49229
# Score for group all_id: 0.20983
# Score for group cat_id: 0.25335
# Score for group state_id: 0.29509
# Score for group dept_id: 0.34001
# Score for group store_id: 0.38659
# Score for group item_id: 0.80571
# Score for group ['state_id', 'cat_id']: 0.3547
# Score for group ['state_id', 'dept_id']: 0.44052
# Score for group ['store_id', 'cat_id']: 0.45421
# Score for group ['store_id', 'dept_id']: 0.54855
# Score for group ['item_id', 'state_id']: 0.81674
# Score for group ['item_id', 'store_id']: 0.8217
#
# Public LB Score: 0.47725
# Score for group all_id: 0.18552
# Score for group cat_id: 0.23609
# Score for group state_id: 0.28206
# Score for group dept_id: 0.34241
# Score for group store_id: 0.38031
# Score for group item_id: 0.80736
# Score for group ['state_id', 'cat_id']: 0.34598
# Score for group ['state_id', 'dept_id']: 0.44211
# Score for group ['store_id', 'cat_id']: 0.4495
# Score for group ['store_id', 'dept_id']: 0.54901
# Score for group ['item_id', 'state_id']: 0.81771
# Score for group ['item_id', 'store_id']: 0.82247
#
# Public LB Score: 0.47171
# Score for group all_id: 0.18973
# Score for group cat_id: 0.2395
# Score for group state_id: 0.2867
# Score for group dept_id: 0.36089
# Score for group store_id: 0.38401
# Score for group item_id: 0.80986
# Score for group ['state_id', 'cat_id']: 0.34996
# Score for group ['state_id', 'dept_id']: 0.45261
# Score for group ['store_id', 'cat_id']: 0.45185
# Score for group ['store_id', 'dept_id']: 0.55448
# Score for group ['item_id', 'state_id']: 0.81911
# Score for group ['item_id', 'store_id']: 0.82344
#
# Public LB Score: 0.47684
# Score for group all_id: 0.22082
# Score for group cat_id: 0.2641
# Score for group state_id: 0.30737
# Score for group dept_id: 0.3918
# Score for group store_id: 0.39713
# Score for group item_id: 0.81319
# Score for group ['state_id', 'cat_id']: 0.36588
# Score for group ['state_id', 'dept_id']: 0.47098
# Score for group ['store_id', 'cat_id']: 0.46121
# Score for group ['store_id', 'dept_id']: 0.56485
# Score for group ['item_id', 'state_id']: 0.82095
# Score for group ['item_id', 'store_id']: 0.82459
#
# Public LB Score: 0.49191
# Score for group all_id: 1.31117
# Score for group cat_id: 1.26149
# Score for group state_id: 1.22421
# Score for group dept_id: 1.234
# Score for group store_id: 1.18333
# Score for group item_id: 0.89627
# Score for group ['state_id', 'cat_id']: 1.17093
# Score for group ['state_id', 'dept_id']: 1.138
# Score for group ['store_id', 'cat_id']: 1.10488
# Score for group ['store_id', 'dept_id']: 1.05496
# Score for group ['item_id', 'state_id']: 0.86092
# Score for group ['item_id', 'store_id']: 0.83518
#
# Public LB Score: 1.10628
# Score for group all_id: 1.23716
# Score for group cat_id: 1.1909
# Score for group state_id: 1.15769
# Score for group dept_id: 1.16606
# Score for group store_id: 1.12152
# Score for group item_id: 0.88466
# Score for group ['state_id', 'cat_id']: 1.10945
# Score for group ['state_id', 'dept_id']: 1.08052
# Score for group ['store_id', 'cat_id']: 1.05105
# Score for group ['store_id', 'dept_id']: 1.00775
# Score for group ['item_id', 'state_id']: 0.85505
# Score for group ['item_id', 'store_id']: 0.83293
#
# Public LB Score: 1.0579
# Score for group all_id: 1.16325
# Score for group cat_id: 1.12048
# Score for group state_id: 1.09141
# Score for group dept_id: 1.09841
# Score for group store_id: 1.06009
# Score for group item_id: 0.87375
# Score for group ['state_id', 'cat_id']: 1.04835
# Score for group ['state_id', 'dept_id']: 1.02359
# Score for group ['store_id', 'cat_id']: 0.99777
# Score for group ['store_id', 'dept_id']: 0.96137
# Score for group ['item_id', 'state_id']: 0.84956
# Score for group ['item_id', 'store_id']: 0.83086
#
# Public LB Score: 1.00991
# Score for group all_id: 1.08945
# Score for group cat_id: 1.05026
# Score for group state_id: 1.02543
# Score for group dept_id: 1.03111
# Score for group store_id: 0.99913
# Score for group item_id: 0.86355
# Score for group ['state_id', 'cat_id']: 0.98767
# Score for group ['state_id', 'dept_id']: 0.96729
# Score for group ['store_id', 'cat_id']: 0.94516
# Score for group ['store_id', 'dept_id']: 0.91594
# Score for group ['item_id', 'state_id']: 0.84445
# Score for group ['item_id', 'store_id']: 0.82898
#
# Public LB Score: 0.96237
# Score for group all_id: 1.01581
# Score for group cat_id: 0.9803
# Score for group state_id: 0.95979
# Score for group dept_id: 0.96423
# Score for group store_id: 0.93871
# Score for group item_id: 0.85409
# Score for group ['state_id', 'cat_id']: 0.92752
# Score for group ['state_id', 'dept_id']: 0.91176
# Score for group ['store_id', 'cat_id']: 0.89333
# Score for group ['store_id', 'dept_id']: 0.87164
# Score for group ['item_id', 'state_id']: 0.83975
# Score for group ['item_id', 'store_id']: 0.82728
#
# Public LB Score: 0.91535
# Score for group all_id: 0.94234
# Score for group cat_id: 0.91063
# Score for group state_id: 0.89457
# Score for group dept_id: 0.89789
# Score for group store_id: 0.87896
# Score for group item_id: 0.8454
# Score for group ['state_id', 'cat_id']: 0.86799
# Score for group ['state_id', 'dept_id']: 0.85715
# Score for group ['store_id', 'cat_id']: 0.84244
# Score for group ['store_id', 'dept_id']: 0.82869
# Score for group ['item_id', 'state_id']: 0.83544
# Score for group ['item_id', 'store_id']: 0.82576
#
# Public LB Score: 0.86894
# Score for group all_id: 0.8691
# Score for group cat_id: 0.84136
# Score for group state_id: 0.82987
# Score for group dept_id: 0.83221
# Score for group store_id: 0.82003
# Score for group item_id: 0.83749
# Score for group ['state_id', 'cat_id']: 0.80921
# Score for group ['state_id', 'dept_id']: 0.80365
# Score for group ['store_id', 'cat_id']: 0.79269
# Score for group ['store_id', 'dept_id']: 0.78736
# Score for group ['item_id', 'state_id']: 0.83156
# Score for group ['item_id', 'store_id']: 0.82444
#
# Public LB Score: 0.82325
# Score for group all_id: 0.79615
# Score for group cat_id: 0.77257
# Score for group state_id: 0.76582
# Score for group dept_id: 0.76739
# Score for group store_id: 0.76214
# Score for group item_id: 0.83041
# Score for group ['state_id', 'cat_id']: 0.75137
# Score for group ['state_id', 'dept_id']: 0.75149
# Score for group ['store_id', 'cat_id']: 0.74431
# Score for group ['store_id', 'dept_id']: 0.74796
# Score for group ['item_id', 'state_id']: 0.82809
# Score for group ['item_id', 'store_id']: 0.8233
#
# Public LB Score: 0.77842
# Score for group all_id: 0.72357
# Score for group cat_id: 0.70442
# Score for group state_id: 0.70258
# Score for group dept_id: 0.70368
# Score for group store_id: 0.70555
# Score for group item_id: 0.82415
# Score for group ['state_id', 'cat_id']: 0.69468
# Score for group ['state_id', 'dept_id']: 0.70097
# Score for group ['store_id', 'cat_id']: 0.69764
# Score for group ['store_id', 'dept_id']: 0.71091
# Score for group ['item_id', 'state_id']: 0.82505
# Score for group ['item_id', 'store_id']: 0.82235
#
# Public LB Score: 0.73463
# Score for group all_id: 0.65149
# Score for group cat_id: 0.63712
# Score for group state_id: 0.6404
# Score for group dept_id: 0.64147
# Score for group store_id: 0.65064
# Score for group item_id: 0.81875
# Score for group ['state_id', 'cat_id']: 0.63943
# Score for group ['state_id', 'dept_id']: 0.65248
# Score for group ['store_id', 'cat_id']: 0.6531
# Score for group ['store_id', 'dept_id']: 0.67666
# Score for group ['item_id', 'state_id']: 0.82245
# Score for group ['item_id', 'store_id']: 0.82159
#
# Public LB Score: 0.69213
# Score for group all_id: 0.5801
# Score for group cat_id: 0.57096
# Score for group state_id: 0.57958
# Score for group dept_id: 0.58128
# Score for group store_id: 0.59796
# Score for group item_id: 0.81422
# Score for group ['state_id', 'cat_id']: 0.58604
# Score for group ['state_id', 'dept_id']: 0.60654
# Score for group ['store_id', 'cat_id']: 0.6112
# Score for group ['store_id', 'dept_id']: 0.64571
# Score for group ['item_id', 'state_id']: 0.82028
# Score for group ['item_id', 'store_id']: 0.82103
#
# Public LB Score: 0.65124
# Score for group all_id: 0.50969
# Score for group cat_id: 0.50643
# Score for group state_id: 0.52061
# Score for group dept_id: 0.52391
# Score for group store_id: 0.54825
# Score for group item_id: 0.81056
# Score for group ['state_id', 'cat_id']: 0.53505
# Score for group ['state_id', 'dept_id']: 0.56381
# Score for group ['store_id', 'cat_id']: 0.57261
# Score for group ['store_id', 'dept_id']: 0.61849
# Score for group ['item_id', 'state_id']: 0.81856
# Score for group ['item_id', 'store_id']: 0.82066
#
# Public LB Score: 0.61239
# Score for group all_id: 0.44071
# Score for group cat_id: 0.44424
# Score for group state_id: 0.46416
# Score for group dept_id: 0.47052
# Score for group store_id: 0.50252
# Score for group item_id: 0.80779
# Score for group ['state_id', 'cat_id']: 0.4872
# Score for group ['state_id', 'dept_id']: 0.52526
# Score for group ['store_id', 'cat_id']: 0.53805
# Score for group ['store_id', 'dept_id']: 0.59539
# Score for group ['item_id', 'state_id']: 0.81729
# Score for group ['item_id', 'store_id']: 0.82048
#
# Public LB Score: 0.57613
# Score for group all_id: 0.37399
# Score for group cat_id: 0.38553
# Score for group state_id: 0.41127
# Score for group dept_id: 0.42279
# Score for group store_id: 0.46208
# Score for group item_id: 0.80592
# Score for group ['state_id', 'cat_id']: 0.44356
# Score for group ['state_id', 'dept_id']: 0.49214
# Score for group ['store_id', 'cat_id']: 0.5083
# Score for group ['store_id', 'dept_id']: 0.57665
# Score for group ['item_id', 'state_id']: 0.81647
# Score for group ['item_id', 'store_id']: 0.82049
#
# Public LB Score: 0.54327
# Score for group all_id: 0.31095
# Score for group cat_id: 0.33214
# Score for group state_id: 0.36355
# Score for group dept_id: 0.38305
# Score for group store_id: 0.4284
# Score for group item_id: 0.80494
# Score for group ['state_id', 'cat_id']: 0.40558
# Score for group ['state_id', 'dept_id']: 0.46602
# Score for group ['store_id', 'cat_id']: 0.48406
# Score for group ['store_id', 'dept_id']: 0.5625
# Score for group ['item_id', 'state_id']: 0.8161
# Score for group ['item_id', 'store_id']: 0.8207
#
# Public LB Score: 0.51483
# Score for group all_id: 0.25436
# Score for group cat_id: 0.2868
# Score for group state_id: 0.32354
# Score for group dept_id: 0.35428
# Score for group store_id: 0.40287
# Score for group item_id: 0.80484
# Score for group ['state_id', 'cat_id']: 0.37518
# Score for group ['state_id', 'dept_id']: 0.44847
# Score for group ['store_id', 'cat_id']: 0.46591
# Score for group ['store_id', 'dept_id']: 0.5531
# Score for group ['item_id', 'state_id']: 0.81617
# Score for group ['item_id', 'store_id']: 0.82109
#
# Public LB Score: 0.49222
# Score for group all_id: 0.20952
# Score for group cat_id: 0.25322
# Score for group state_id: 0.29491
# Score for group dept_id: 0.33985
# Score for group store_id: 0.38663
# Score for group item_id: 0.80563
# Score for group ['state_id', 'cat_id']: 0.35463
# Score for group ['state_id', 'dept_id']: 0.44046
# Score for group ['store_id', 'cat_id']: 0.4543
# Score for group ['store_id', 'dept_id']: 0.54859
# Score for group ['item_id', 'state_id']: 0.81669
# Score for group ['item_id', 'store_id']: 0.82168
#
# Public LB Score: 0.47718
# Score for group all_id: 0.18516
# Score for group cat_id: 0.23595
# Score for group state_id: 0.28186
# Score for group dept_id: 0.34229
# Score for group store_id: 0.38033
# Score for group item_id: 0.80728
# Score for group ['state_id', 'cat_id']: 0.3459
# Score for group ['state_id', 'dept_id']: 0.44206
# Score for group ['store_id', 'cat_id']: 0.44958
# Score for group ['store_id', 'dept_id']: 0.54906
# Score for group ['item_id', 'state_id']: 0.81766
# Score for group ['item_id', 'store_id']: 0.82246
#
# Public LB Score: 0.47163
# Score for group all_id: 0.18935
# Score for group cat_id: 0.23932
# Score for group state_id: 0.28649
# Score for group dept_id: 0.36082
# Score for group store_id: 0.38402
# Score for group item_id: 0.80979
# Score for group ['state_id', 'cat_id']: 0.34987
# Score for group ['state_id', 'dept_id']: 0.45259
# Score for group ['store_id', 'cat_id']: 0.45192
# Score for group ['store_id', 'dept_id']: 0.55452
# Score for group ['item_id', 'state_id']: 0.81906
# Score for group ['item_id', 'store_id']: 0.82342
#
# Public LB Score: 0.47677
# Score for group all_id: 0.22048
# Score for group cat_id: 0.26392
# Score for group state_id: 0.30717
# Score for group dept_id: 0.39177
# Score for group store_id: 0.39712
# Score for group item_id: 0.81312
# Score for group ['state_id', 'cat_id']: 0.3658
# Score for group ['state_id', 'dept_id']: 0.47098
# Score for group ['store_id', 'cat_id']: 0.46126
# Score for group ['store_id', 'dept_id']: 0.56489
# Score for group ['item_id', 'state_id']: 0.8209
# Score for group ['item_id', 'store_id']: 0.82458
#
# Public LB Score: 0.49183
# Score for group all_id: 0.26937
# Score for group cat_id: 0.30481
# Score for group state_id: 0.34032
# Score for group dept_id: 0.43141
# Score for group store_id: 0.41875
# Score for group item_id: 0.81727
# Score for group ['state_id', 'cat_id']: 0.3919
# Score for group ['state_id', 'dept_id']: 0.49606
# Score for group ['store_id', 'cat_id']: 0.47724
# Score for group ['store_id', 'dept_id']: 0.57997
# Score for group ['item_id', 'state_id']: 0.82317
# Score for group ['item_id', 'store_id']: 0.82591
#
# Public LB Score: 0.51468
# Score for group all_id: 1.23714
# Score for group cat_id: 1.19081
# Score for group state_id: 1.1577
# Score for group dept_id: 1.16597
# Score for group store_id: 1.12154
# Score for group item_id: 0.88458
# Score for group ['state_id', 'cat_id']: 1.10942
# Score for group ['state_id', 'dept_id']: 1.08047
# Score for group ['store_id', 'cat_id']: 1.05103
# Score for group ['store_id', 'dept_id']: 1.00771
# Score for group ['item_id', 'state_id']: 0.855
# Score for group ['item_id', 'store_id']: 0.83292
#
# Public LB Score: 1.05786
# Score for group all_id: 1.16322
# Score for group cat_id: 1.12038
# Score for group state_id: 1.09142
# Score for group dept_id: 1.09831
# Score for group store_id: 1.06012
# Score for group item_id: 0.87366
# Score for group ['state_id', 'cat_id']: 1.04831
# Score for group ['state_id', 'dept_id']: 1.02352
# Score for group ['store_id', 'cat_id']: 0.99776
# Score for group ['store_id', 'dept_id']: 0.96132
# Score for group ['item_id', 'state_id']: 0.84951
# Score for group ['item_id', 'store_id']: 0.83085
#
# Public LB Score: 1.00987
# Score for group all_id: 1.08943
# Score for group cat_id: 1.05016
# Score for group state_id: 1.02543
# Score for group dept_id: 1.03101
# Score for group store_id: 0.99915
# Score for group item_id: 0.86346
# Score for group ['state_id', 'cat_id']: 0.98763
# Score for group ['state_id', 'dept_id']: 0.96723
# Score for group ['store_id', 'cat_id']: 0.94515
# Score for group ['store_id', 'dept_id']: 0.91589
# Score for group ['item_id', 'state_id']: 0.8444
# Score for group ['item_id', 'store_id']: 0.82897
#
# Public LB Score: 0.96233
# Score for group all_id: 1.01578
# Score for group cat_id: 0.98019
# Score for group state_id: 0.95979
# Score for group dept_id: 0.96413
# Score for group store_id: 0.93873
# Score for group item_id: 0.854
# Score for group ['state_id', 'cat_id']: 0.92748
# Score for group ['state_id', 'dept_id']: 0.91169
# Score for group ['store_id', 'cat_id']: 0.89332
# Score for group ['store_id', 'dept_id']: 0.8716
# Score for group ['item_id', 'state_id']: 0.83969
# Score for group ['item_id', 'store_id']: 0.82726
#
# Public LB Score: 0.9153
# Score for group all_id: 0.9423
# Score for group cat_id: 0.91053
# Score for group state_id: 0.89457
# Score for group dept_id: 0.89778
# Score for group store_id: 0.87898
# Score for group item_id: 0.84531
# Score for group ['state_id', 'cat_id']: 0.86794
# Score for group ['state_id', 'dept_id']: 0.85708
# Score for group ['store_id', 'cat_id']: 0.84243
# Score for group ['store_id', 'dept_id']: 0.82865
# Score for group ['item_id', 'state_id']: 0.83539
# Score for group ['item_id', 'store_id']: 0.82575
#
# Public LB Score: 0.86889
# Score for group all_id: 0.86906
# Score for group cat_id: 0.84125
# Score for group state_id: 0.82987
# Score for group dept_id: 0.83209
# Score for group store_id: 0.82005
# Score for group item_id: 0.83741
# Score for group ['state_id', 'cat_id']: 0.80917
# Score for group ['state_id', 'dept_id']: 0.80357
# Score for group ['store_id', 'cat_id']: 0.79267
# Score for group ['store_id', 'dept_id']: 0.78731
# Score for group ['item_id', 'state_id']: 0.8315
# Score for group ['item_id', 'store_id']: 0.82442
#
# Public LB Score: 0.8232
# Score for group all_id: 0.7961
# Score for group cat_id: 0.77245
# Score for group state_id: 0.76581
# Score for group dept_id: 0.76726
# Score for group store_id: 0.76215
# Score for group item_id: 0.83032
# Score for group ['state_id', 'cat_id']: 0.75132
# Score for group ['state_id', 'dept_id']: 0.7514
# Score for group ['store_id', 'cat_id']: 0.7443
# Score for group ['store_id', 'dept_id']: 0.74792
# Score for group ['item_id', 'state_id']: 0.82804
# Score for group ['item_id', 'store_id']: 0.82328
#
# Public LB Score: 0.77836
# Score for group all_id: 0.72351
# Score for group cat_id: 0.7043
# Score for group state_id: 0.70257
# Score for group dept_id: 0.70355
# Score for group store_id: 0.70556
# Score for group item_id: 0.82407
# Score for group ['state_id', 'cat_id']: 0.69462
# Score for group ['state_id', 'dept_id']: 0.70087
# Score for group ['store_id', 'cat_id']: 0.69763
# Score for group ['store_id', 'dept_id']: 0.71088
# Score for group ['item_id', 'state_id']: 0.825
# Score for group ['item_id', 'store_id']: 0.82233
#
# Public LB Score: 0.73457
# Score for group all_id: 0.65142
# Score for group cat_id: 0.63699
# Score for group state_id: 0.64038
# Score for group dept_id: 0.64132
# Score for group store_id: 0.65065
# Score for group item_id: 0.81867
# Score for group ['state_id', 'cat_id']: 0.63938
# Score for group ['state_id', 'dept_id']: 0.65238
# Score for group ['store_id', 'cat_id']: 0.65309
# Score for group ['store_id', 'dept_id']: 0.67664
# Score for group ['item_id', 'state_id']: 0.82239
# Score for group ['item_id', 'store_id']: 0.82158
#
# Public LB Score: 0.69207
# Score for group all_id: 0.58002
# Score for group cat_id: 0.57083
# Score for group state_id: 0.57955
# Score for group dept_id: 0.58112
# ...
#
# Public LB Score: 0.6906
# Score for group all_id: 0.66993
# Score for group cat_id: 0.67124
# Score for group state_id: 0.65953
# Score for group dept_id: 0.75101
# Score for group store_id: 0.67002
# Score for group item_id: 0.85797
# Score for group ['state_id', 'cat_id']: 0.66674
# Score for group ['state_id', 'dept_id']: 0.73439
# Score for group ['store_id', 'cat_id']: 0.67858
# Score for group ['store_id', 'dept_id']: 0.7485
# Score for group ['item_id', 'state_id']: 0.84519
# Score for group ['item_id', 'store_id']: 0.83776
#
# Public LB Score: 0.73257
# Score for group all_id: 0.74228
# Score for group cat_id: 0.73928
# Score for group state_id: 0.72173
# Score for group dept_id: 0.81017
# Score for group store_id: 0.72419
# Score for group item_id: 0.8673
# Score for group ['state_id', 'cat_id']: 0.72254
# Score for group ['state_id', 'dept_id']: 0.78238
# Score for group ['store_id', 'cat_id']: 0.72375
# Score for group ['store_id', 'dept_id']: 0.78555
# Score for group ['item_id', 'state_id']: 0.85026
# Score for group ['item_id', 'store_id']: 0.84033
#
# Public LB Score: 0.77581
# Score for group all_id: 0.81507
# Score for group cat_id: 0.80798
# Score for group state_id: 0.78497
# Score for group dept_id: 0.87031
# Score for group store_id: 0.78016
# Score for group item_id: 0.87727
# Score for group ['state_id', 'cat_id']: 0.77967
# Score for group ['state_id', 'dept_id']: 0.83182
# Score for group ['store_id', 'cat_id']: 0.77086
# Score for group ['store_id', 'dept_id']: 0.82436
# Score for group ['item_id', 'state_id']: 0.85569
# Score for group ['item_id', 'store_id']: 0.84307
#
# Public LB Score: 0.8201
# Score for group all_id: 0.88819
# Score for group cat_id: 0.87719
# Score for group state_id: 0.84902
# Score for group dept_id: 0.93136
# Score for group store_id: 0.83754
# Score for group item_id: 0.88787
# Score for group ['state_id', 'cat_id']: 0.83786
# Score for group ['state_id', 'dept_id']: 0.88252
# Score for group ['store_id', 'cat_id']: 0.81956
# Score for group ['store_id', 'dept_id']: 0.8647
# Score for group ['item_id', 'state_id']: 0.86146
# Score for group ['item_id', 'store_id']: 0.84596
#
# Public LB Score: 0.86527
# Score for group all_id: 0.96157
# Score for group cat_id: 0.94681
# Score for group state_id: 0.91372
# Score for group dept_id: 0.99326
# Score for group store_id: 0.89605
# Score for group item_id: 0.89906
# Score for group ['state_id', 'cat_id']: 0.89691
# Score for group ['state_id', 'dept_id']: 0.93435
# Score for group ['store_id', 'cat_id']: 0.86956
# Score for group ['store_id', 'dept_id']: 0.90637
# Score for group ['item_id', 'state_id']: 0.86758
# Score for group ['item_id', 'store_id']: 0.84902
#
# Public LB Score: 0.91119
# Score for group all_id: 1.03515
# Score for group cat_id: 1.01674
# Score for group state_id: 0.97893
# Score for group dept_id: 1.05597
# Score for group store_id: 0.95546
# Score for group item_id: 0.91082
# Score for group ['state_id', 'cat_id']: 0.95667
# Score for group ['state_id', 'dept_id']: 0.98717
# Score for group ['store_id', 'cat_id']: 0.92063
# Score for group ['store_id', 'dept_id']: 0.9492
# Score for group ['item_id', 'state_id']: 0.87402
# Score for group ['item_id', 'store_id']: 0.85223
#
# Public LB Score: 0.95775
# Score for group all_id: 1.1089
# Score for group cat_id: 1.08693
# Score for group state_id: 1.04456
# Score for group dept_id: 1.11946
# Score for group store_id: 1.0156
# Score for group item_id: 0.92315
# Score for group ['state_id', 'cat_id']: 1.01701
# Score for group ['state_id', 'dept_id']: 1.04089
# Score for group ['store_id', 'cat_id']: 0.9726
# Score for group ['store_id', 'dept_id']: 0.99307
# Score for group ['item_id', 'state_id']: 0.88079
# Score for group ['item_id', 'store_id']: 0.8556
#
# Public LB Score: 1.00488
# Score for group all_id: 1.18277
# Score for group cat_id: 1.15733
# Score for group state_id: 1.11055
# Score for group dept_id: 1.18369
# Score for group store_id: 1.07634
# Score for group item_id: 0.93602
# Score for group ['state_id', 'cat_id']: 1.07784
# Score for group ['state_id', 'dept_id']: 1.09541
# Score for group ['store_id', 'cat_id']: 1.02533
# Score for group ['store_id', 'dept_id']: 1.03785
# Score for group ['item_id', 'state_id']: 0.88787
# Score for group ['item_id', 'store_id']: 0.85911
#
# Public LB Score: 1.05251
# Score for group all_id: 1.25675
# Score for group cat_id: 1.22791
# Score for group state_id: 1.17682
# Score for group dept_id: 1.24862
# Score for group store_id: 1.13757
# Score for group item_id: 0.94941
# Score for group ['state_id', 'cat_id']: 1.13908
# Score for group ['state_id', 'dept_id']: 1.15066
# Score for group ['store_id', 'cat_id']: 1.0787
# Score for group ['store_id', 'dept_id']: 1.08345
# Score for group ['item_id', 'state_id']: 0.89525
# Score for group ['item_id', 'store_id']: 0.86278
#
# Public LB Score: 1.10058
# Score for group all_id: 1.33082
# Score for group cat_id: 1.29863
# Score for group state_id: 1.24334
# Score for group dept_id: 1.31417
# Score for group store_id: 1.19922
# Score for group item_id: 0.96331
# Score for group ['state_id', 'cat_id']: 1.20067
# Score for group ['state_id', 'dept_id']: 1.20655
# Score for group ['store_id', 'cat_id']: 1.13261
# Score for group ['store_id', 'dept_id']: 1.12976
# Score for group ['item_id', 'state_id']: 0.90293
# Score for group ['item_id', 'store_id']: 0.86659
#
# Public LB Score: 1.14905
# Score for group all_id: 0.20565
# Score for group cat_id: 0.25234
# Score for group state_id: 0.29297
# Score for group dept_id: 0.33862
# Score for group store_id: 0.38822
# Score for group item_id: 0.80482
# Score for group ['state_id', 'cat_id']: 0.35443
# Score for group ['state_id', 'dept_id']: 0.44049
# Score for group ['store_id', 'cat_id']: 0.45667
# Score for group ['store_id', 'dept_id']: 0.55024
# Score for group ['item_id', 'state_id']: 0.81627
# Score for group ['item_id', 'store_id']: 0.82172
#
# Public LB Score: 0.47687
# Score for group all_id: 0.18053
# Score for group cat_id: 0.23493
# Score for group state_id: 0.27955
# Score for group dept_id: 0.34166
# Score for group store_id: 0.3817
# Score for group item_id: 0.80652
# Score for group ['state_id', 'cat_id']: 0.34569
# Score for group ['state_id', 'dept_id']: 0.44241
# Score for group ['store_id', 'cat_id']: 0.45186
# Score for group ['store_id', 'dept_id']: 0.55067
# Score for group ['item_id', 'state_id']: 0.81726
# Score for group ['item_id', 'store_id']: 0.8225
#
# Public LB Score: 0.47127
# Score for group all_id: 0.1846
# Score for group cat_id: 0.23781
# Score for group state_id: 0.28408
# Score for group dept_id: 0.36076
# Score for group store_id: 0.38508
# Score for group item_id: 0.80908
# Score for group ['state_id', 'cat_id']: 0.34954
# Score for group ['state_id', 'dept_id']: 0.45319
# Score for group ['store_id', 'cat_id']: 0.45397
# Score for group ['store_id', 'dept_id']: 0.55606
# Score for group ['item_id', 'state_id']: 0.81869
# Score for group ['item_id', 'store_id']: 0.82347
#
# Public LB Score: 0.47636
# Score for group all_id: 0.21621
# Score for group cat_id: 0.26207
# Score for group state_id: 0.30487
# Score for group dept_id: 0.39223
# Score for group store_id: 0.39786
# Score for group item_id: 0.81248
# Score for group ['state_id', 'cat_id']: 0.36532
# Score for group ['state_id', 'dept_id']: 0.47179
# Score for group ['store_id', 'cat_id']: 0.46297
# Score for group ['store_id', 'dept_id']: 0.56633
# Score for group ['item_id', 'state_id']: 0.82055
# Score for group ['item_id', 'store_id']: 0.82463
#
# Public LB Score: 0.49144
# Score for group all_id: 0.26572
# Score for group cat_id: 0.30301
# Score for group state_id: 0.33821
# Score for group dept_id: 0.43231
# Score for group store_id: 0.41915
# Score for group item_id: 0.8167
# Score for group ['state_id', 'cat_id']: 0.3913
# Score for group ['state_id', 'dept_id']: 0.49706
# Score for group ['store_id', 'cat_id']: 0.47857
# Score for group ['store_id', 'dept_id']: 0.5813
# Score for group ['item_id', 'state_id']: 0.82285
# Score for group ['item_id', 'store_id']: 0.82597
#
# Public LB Score: 0.51435
# Score for group all_id: 0.32504
# Score for group cat_id: 0.35448
# Score for group state_id: 0.3806
# Score for group dept_id: 0.47827
# Score for group store_id: 0.44794
# Score for group item_id: 0.82172
# Score for group ['state_id', 'cat_id']: 0.4255
# Score for group ['state_id', 'dept_id']: 0.52783
# Score for group ['store_id', 'cat_id']: 0.50029
# Score for group ['store_id', 'dept_id']: 0.60066
# Score for group ['item_id', 'state_id']: 0.82557
# Score for group ['item_id', 'store_id']: 0.8275
#
# Public LB Score: 0.54295
# Score for group all_id: 0.38972
# Score for group cat_id: 0.41225
# Score for group state_id: 0.42943
# Score for group dept_id: 0.52832
# Score for group store_id: 0.48319
# Score for group item_id: 0.82752
# Score for group ['state_id', 'cat_id']: 0.46608
# Score for group ['state_id', 'dept_id']: 0.56311
# Score for group ['store_id', 'cat_id']: 0.52753
# Score for group ['store_id', 'dept_id']: 0.624
# Score for group ['item_id', 'state_id']: 0.8287
# Score for group ['item_id', 'store_id']: 0.8292
#
# Public LB Score: 0.57575
# Score for group all_id: 0.4575
# Score for group cat_id: 0.47393
# Score for group state_id: 0.48284
# Score for group dept_id: 0.58127
# Score for group store_id: 0.52391
# Score for group item_id: 0.83406
# Score for group ['state_id', 'cat_id']: 0.51153
# Score for group ['state_id', 'dept_id']: 0.60203
# Score for group ['store_id', 'cat_id']: 0.55965
# Score for group ['store_id', 'dept_id']: 0.65089
# Score for group ['item_id', 'state_id']: 0.83224
# Score for group ['item_id', 'store_id']: 0.83108
#
# Public LB Score: 0.61174
# Score for group all_id: 0.52717
# Score for group cat_id: 0.53814
# Score for group state_id: 0.53952
# Score for group dept_id: 0.63636
# Score for group store_id: 0.56917
# Score for group item_id: 0.84134
# Score for group ['state_id', 'cat_id']: 0.56067
# Score for group ['state_id', 'dept_id']: 0.64391
# Score for group ['store_id', 'cat_id']: 0.59597
# Score for group ['store_id', 'dept_id']: 0.68088
# Score for group ['item_id', 'state_id']: 0.83618
# Score for group ['item_id', 'store_id']: 0.83314
#
# Public LB Score: 0.6502
# Score for group all_id: 0.59808
# Score for group cat_id: 0.60408
# Score for group state_id: 0.5986
# Score for group dept_id: 0.69308
# Score for group store_id: 0.61811
# Score for group item_id: 0.84933
# Score for group ['state_id', 'cat_id']: 0.61262
# Score for group ['state_id', 'dept_id']: 0.6882
# Score for group ['store_id', 'cat_id']: 0.63582
# Score for group ['store_id', 'dept_id']: 0.71356
# Score for group ['item_id', 'state_id']: 0.8405
# Score for group ['item_id', 'store_id']: 0.83538
#
# Public LB Score: 0.69061
# Score for group all_id: 0.66984
# Score for group cat_id: 0.67123
# Score for group state_id: 0.65946
# Score for group dept_id: 0.75113
# Score for group store_id: 0.66997
# Score for group item_id: 0.858
# Score for group ['state_id', 'cat_id']: 0.66673
# Score for group ['state_id', 'dept_id']: 0.7345
# Score for group ['store_id', 'cat_id']: 0.67859
# Score for group ['store_id', 'dept_id']: 0.74859
# Score for group ['item_id', 'state_id']: 0.8452
# Score for group ['item_id', 'store_id']: 0.83778
#
# Public LB Score: 0.73259
# Score for group all_id: 0.74219
# Score for group cat_id: 0.73927
# Score for group state_id: 0.72167
# Score for group dept_id: 0.81028
# Score for group store_id: 0.72414
# Score for group item_id: 0.86733
# Score for group ['state_id', 'cat_id']: 0.72253
# Score for group ['state_id', 'dept_id']: 0.78248
# Score for group ['store_id', 'cat_id']: 0.72375
# Score for group ['store_id', 'dept_id']: 0.78564
# Score for group ['item_id', 'state_id']: 0.85027
# Score for group ['item_id', 'store_id']: 0.84035
#
# Public LB Score: 0.77583
# Score for group all_id: 0.81499
# Score for group cat_id: 0.80798
# Score for group state_id: 0.78491
# Score for group dept_id: 0.87041
# Score for group store_id: 0.7801
# Score for group item_id: 0.87731
# Score for group ['state_id', 'cat_id']: 0.77966
# Score for group ['state_id', 'dept_id']: 0.83191
# Score for group ['store_id', 'cat_id']: 0.77085
# Score for group ['store_id', 'dept_id']: 0.82444
# Score for group ['item_id', 'state_id']: 0.8557
# Score for group ['item_id', 'store_id']: 0.84309
#
# Public LB Score: 0.82011
# Score for group all_id: 0.88811
# Score for group cat_id: 0.8772
# Score for group state_id: 0.84896
# Score for group dept_id: 0.93144
# Score for group store_id: 0.83748
# Score for group item_id: 0.8879
# Score for group ['state_id', 'cat_id']: 0.83786
# Score for group ['state_id', 'dept_id']: 0.88261
# Score for group ['store_id', 'cat_id']: 0.81955
# Score for group ['store_id', 'dept_id']: 0.86477
# Score for group ['item_id', 'state_id']: 0.86148
# Score for group ['item_id', 'store_id']: 0.84598
#
# Public LB Score: 0.86528
# Score for group all_id: 0.9615
# Score for group cat_id: 0.94682
# Score for group state_id: 0.91366
# Score for group dept_id: 0.99333
# Score for group store_id: 0.89599
# Score for group item_id: 0.8991
# Score for group ['state_id', 'cat_id']: 0.89691
# Score for group ['state_id', 'dept_id']: 0.93443
# Score for group ['store_id', 'cat_id']: 0.86954
# Score for group ['store_id', 'dept_id']: 0.90643
# Score for group ['item_id', 'state_id']: 0.8676
# Score for group ['item_id', 'store_id']: 0.84904
#
# Public LB Score: 0.9112
# Score for group all_id: 1.03508
# Score for group cat_id: 1.01675
# Score for group state_id: 0.97887
# Score for group dept_id: 1.05603
# Score for group store_id: 0.9554
# Score for group item_id: 0.91087
# Score for group ['state_id', 'cat_id']: 0.95667
# Score for group ['state_id', 'dept_id']: 0.98724
# Score for group ['store_id', 'cat_id']: 0.92061
# Score for group ['store_id', 'dept_id']: 0.94926
# Score for group ['item_id', 'state_id']: 0.87405
# Score for group ['item_id', 'store_id']: 0.85225
#
# Public LB Score: 0.95776
# Score for group all_id: 1.10882
# Score for group cat_id: 1.08695
# Score for group state_id: 1.04451
# Score for group dept_id: 1.11951
# Score for group store_id: 1.01554
# Score for group item_id: 0.92321
# Score for group ['state_id', 'cat_id']: 1.01701
# Score for group ['state_id', 'dept_id']: 1.04095
# Score for group ['store_id', 'cat_id']: 0.97258
# Score for group ['store_id', 'dept_id']: 0.99313
# Score for group ['item_id', 'state_id']: 0.88081
# Score for group ['item_id', 'store_id']: 0.85562
#
# Public LB Score: 1.00489
# Score for group all_id: 1.1827
# Score for group cat_id: 1.15735
# Score for group state_id: 1.11049
# Score for group dept_id: 1.18373
# Score for group store_id: 1.07627
# Score for group item_id: 0.93608
# Score for group ['state_id', 'cat_id']: 1.07784
# Score for group ['state_id', 'dept_id']: 1.09547
# Score for group ['store_id', 'cat_id']: 1.02531
# Score for group ['store_id', 'dept_id']: 1.0379
# Score for group ['item_id', 'state_id']: 0.8879
# Score for group ['item_id', 'store_id']: 0.85914
#
# Public LB Score: 1.05251
# Score for group all_id: 1.25668
# Score for group cat_id: 1.22793
# Score for group state_id: 1.17677
# Score for group dept_id: 1.24864
# Score for group store_id: 1.13751
# Score for group item_id: 0.94947
# Score for group ['state_id', 'cat_id']: 1.13908
# Score for group ['state_id', 'dept_id']: 1.1507
# Score for group ['store_id', 'cat_id']: 1.07868
# Score for group ['store_id', 'dept_id']: 1.08349
# Score for group ['item_id', 'state_id']: 0.89528
# Score for group ['item_id', 'store_id']: 0.8628
#
# Public LB Score: 1.10059
# Score for group all_id: 1.33076
# Score for group cat_id: 1.29865
# Score for group state_id: 1.24329
# Score for group dept_id: 1.31418
# Score for group store_id: 1.19916
# Score for group item_id: 0.96337
# Score for group ['state_id', 'cat_id']: 1.20067
# Score for group ['state_id', 'dept_id']: 1.20659
# Score for group ['store_id', 'cat_id']: 1.13259
# Score for group ['store_id', 'dept_id']: 1.12981
# Score for group ['item_id', 'state_id']: 0.90296
# Score for group ['item_id', 'store_id']: 0.86661
#
# Public LB Score: 1.14905
# Score for group all_id: 1.40491
# Score for group cat_id: 1.3695
# Score for group state_id: 1.31001
# Score for group dept_id: 1.38028
# Score for group store_id: 1.26115
# Score for group item_id: 0.97776
# Score for group ['state_id', 'cat_id']: 1.26256
# Score for group ['state_id', 'dept_id']: 1.26304
# Score for group ['store_id', 'cat_id']: 1.18698
# Score for group ['store_id', 'dept_id']: 1.17677
# Score for group ['item_id', 'state_id']: 0.91092
# Score for group ['item_id', 'store_id']: 0.87056
#
# Public LB Score: 1.19787

# %%
params
# Out:
# {'param1': 0.33, 'param2': 0.67}

# %%
## evaluating submission from public kernel M5 First Public Notebook Under 0.50
## from https://www.kaggle.com/kneroma/m5-first-public-notebook-under-0-50
preds_valid = df_submission[df_submission.id.str.contains("validation")]
preds_valid = preds_valid.merge(df_sample_submission[["id", "order"]], on = "id").sort_values("order").drop(["id", "order"], axis = 1).reset_index(drop = True)
preds_valid.rename(columns = {
    "F1": "d_1914", "F2": "d_1915", "F3": "d_1916", "F4": "d_1917", "F5": "d_1918", "F6": "d_1919", "F7": "d_1920",
    "F8": "d_1921", "F9": "d_1922", "F10": "d_1923", "F11": "d_1924", "F12": "d_1925", "F13": "d_1926", "F14": "d_1927",
    "F15": "d_1928", "F16": "d_1929", "F17": "d_1930", "F18": "d_1931", "F19": "d_1932", "F20": "d_1933", "F21": "d_1934",
    "F22": "d_1935", "F23": "d_1936", "F24": "d_1937", "F25": "d_1938", "F26": "d_1939", "F27": "d_1940", "F28": "d_1941"
}, inplace = True)

groups, scores = evaluator.score(preds_valid)

score_public_lb = np.mean(scores)

for i in range(len(groups)):
    print(f"Score for group {groups[i]}: {round(scores[i], 5)}")

print(f"\nPublic LB Score: {round(score_public_lb, 5)}")
# Out:
# Score for group all_id: 0.39495
# Score for group cat_id: 0.41311
# Score for group state_id: 0.4313
# Score for group dept_id: 0.45867
# Score for group store_id: 0.48321
# Score for group item_id: 0.7795
# Score for group ['state_id', 'cat_id']: 0.47042
# Score for group ['state_id', 'dept_id']: 0.51845
# Score for group ['store_id', 'cat_id']: 0.53186
# Score for group ['store_id', 'dept_id']: 0.59193
# Score for group ['item_id', 'state_id']: 0.79972
# Score for group ['item_id', 'store_id']: 0.81025
#
# Public LB Score: 0.55695

# %% [markdown]
# ## 0. Global
# Lets look at the overall metrics and errors.

# %%
levels = ["all", "category", "state", "department", "store", "item", "state_category", "state_department",
          "store_category", "store_department", "state_item", "store_item"]

df_levels = pd.DataFrame({
    "level": levels,
    "score": scores
})

source_1 = ColumnDataSource(data = dict(
    level = df_levels.level.values,
    score = df_levels.score.values
))

tooltips = [
    ("Level", "@level"),
    ("Score", "@score")
]

v1 = figure(plot_width = 650, plot_height = 400, y_range = df_levels.level.values, tooltips = tooltips, title = "Scores by all aggregation levels")
v1.hbar(y = "level", right = "score", source = source_1, height = 0.75, alpha = 0.6, legend_label = "Public LB Score")

mean = Span(location = np.mean(df_levels.score.values), dimension = "height", line_color = "grey", line_dash = "dashed", line_width = 1.5)
v1.add_layout(mean)

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "Aggregation Level"

v1.legend.location = "bottom_right"


df_levels.sort_values("score", inplace = True)

source_2 = ColumnDataSource(data = dict(
    level = df_levels.level.values,
    score = df_levels.score.values
))

v2 = figure(plot_width = 650, plot_height = 400, y_range = df_levels.level.values, tooltips = tooltips, title = "Scores by all aggregation levels")
v2.hbar(y = "level", right = "score", source = source_2, height = 0.75, alpha = 0.6, legend_label = "Public LB Score")

mean = Span(location = np.mean(df_levels.score.values), dimension = "height", line_color = "grey", line_dash = "dashed", line_width = 1.5)
v2.add_layout(mean)

v2.xaxis.axis_label = "WRMSSE Score"
v2.yaxis.axis_label = "Aggregation Level"

v2.legend.location = "bottom_right"


df_items = df_levels[df_levels.level.str.contains("item")]

source_3 = ColumnDataSource(data = dict(
    level = df_items.level.values,
    score = df_items.score.values
))

v3 = figure(plot_width = 330, plot_height = 200, y_range = df_items.level.values, x_range = Range1d(0, 1), tooltips = tooltips, title = "Scores by item levels")
v3.hbar(y = "level", right = "score", source = source_3, height = 0.75, color = "mediumseagreen", alpha = 0.6)

mean = Span(location = np.mean(df_items.score.values), dimension = "height", line_color = "grey", line_dash = "dashed", line_width = 1.5)
v3.add_layout(mean)

v3.xaxis.axis_label = "WRMSSE Score"
v3.yaxis.axis_label = "Aggregation Level"


df_stores = df_levels[df_levels.level.str.contains("store")]

source_4 = ColumnDataSource(data = dict(
    level = df_stores.level.values,
    score = df_stores.score.values
))

v4 = figure(plot_width = 330, plot_height = 200, y_range = df_stores.level.values, x_range = Range1d(0, 1), tooltips = tooltips, title = "Scores by store levels")
v4.hbar(y = "level", right = "score", source = source_4, height = 0.75, color = "mediumseagreen", alpha = 0.6)

mean = Span(location = np.mean(df_stores.score.values), dimension = "height", line_color = "grey", line_dash = "dashed", line_width = 1.5)
v4.add_layout(mean)

v4.xaxis.axis_label = "WRMSSE Score"
v4.yaxis.axis_label = "Aggregation Level"


df_departments = df_levels[df_levels.level.str.contains("dep")]

source_5 = ColumnDataSource(data = dict(
    level = df_departments.level.values,
    score = df_departments.score.values
))

v5 = figure(plot_width = 330, plot_height = 200, y_range = df_departments.level.values, x_range = Range1d(0, 1), tooltips = tooltips, title = "Scores by department levels")
v5.hbar(y = "level", right = "score", source = source_5, height = 0.75, color = "mediumseagreen", alpha = 0.6)

mean = Span(location = np.mean(df_departments.score.values), dimension = "height", line_color = "grey", line_dash = "dashed", line_width = 1.5)
v5.add_layout(mean)

v5.xaxis.axis_label = "WRMSSE Score"
v5.yaxis.axis_label = "Aggregation Level"


df_states = df_levels[df_levels.level.str.contains("state")]

source_6 = ColumnDataSource(data = dict(
    level = df_states.level.values,
    score = df_states.score.values
))

v6 = figure(plot_width = 330, plot_height = 200, y_range = df_states.level.values, x_range = Range1d(0, 1), tooltips = tooltips, title = "Scores by state levels")
v6.hbar(y = "level", right = "score", source = source_6, height = 0.75, color = "mediumseagreen", alpha = 0.6)

mean = Span(location = np.mean(df_states.score.values), dimension = "height", line_color = "grey", line_dash = "dashed", line_width = 1.5)
v6.add_layout(mean)

v6.xaxis.axis_label = "WRMSSE Score"
v6.yaxis.axis_label = "Aggregation Level"


df_categories = df_levels[df_levels.level.str.contains("cat")]

source_7 = ColumnDataSource(data = dict(
    level = df_categories.level.values,
    score = df_categories.score.values
))

v7 = figure(plot_width = 330, plot_height = 200, y_range = df_categories.level.values, x_range = Range1d(0, 1), tooltips = tooltips, title = "Scores by category levels")
v7.hbar(y = "level", right = "score", source = source_7, height = 0.75, color = "mediumseagreen", alpha = 0.6)

mean = Span(location = np.mean(df_categories.score.values), dimension = "height", line_color = "grey", line_dash = "dashed", line_width = 1.5)
v7.add_layout(mean)

v7.xaxis.axis_label = "WRMSSE Score"
v7.yaxis.axis_label = "Aggregation Level"


show(column(v1, v2, row(v3, v4), row(v5, v6), v7))

# %% [markdown]
# It's clear that the item level aggregations are the hardest to predict. It is inituitive as well due to high volatility and changes in inventory, demand and consumption.
#
# The more rolled up the aggregate levels are the lower the scores are. This is intuitive as well since rolling up tends to cancel out positive and negative errors at granular levels. That is why the singular levels have better scores than the coupled ones. And when all levels are rolled up into ***all*** it is the best.

# %% [markdown]
# ## 1. Store-Item
# Let's look at the most relevant store-item combinations of interest.

# %%
df_store_item = evaluator.get_scores(preds_valid, 12)
df_store_item["store_item_id"] = df_store_item.store_id + "-" + df_store_item.item_id

df_store_item_best = df_store_item.sort_values("score_weighted").head(10).rename(columns = {"score_weighted": "score_best"})
df_store_item_worst = df_store_item.sort_values("score_weighted", ascending = False).head(10).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_store_item_best_worst = pd.concat([df_store_item_best, df_store_item_worst])

source_1 = ColumnDataSource(data = dict(
    store_item_id = df_store_item_best_worst.store_item_id.values,
    score_best = df_store_item_best_worst.score_best.values,
    score_worst = df_store_item_best_worst.score_worst.values
))

tooltips_1 = [
    ("Store-Item", "@store_item_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("Store-Item", "@store_item_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_store_item_best_worst.store_item_id.values, title = "Best and Worst Store-Item")
v11 = v1.hbar("store_item_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("store_item_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "Store-Item"


def get_store_item_plot(df, store_item_id):
    """
    Plots the actual and predicted values of store-item
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.store_item_id == store_item_id, actual_dates].values[0],
        predicted = df.loc[df.store_item_id == store_item_id, predicted_dates].values[0]
    ))
    
    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]
    
    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"store-item = {store_item_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4
    
    return v

v2 = get_store_item_plot(df_store_item, df_store_item_worst.store_item_id.values[-1])
v3 = get_store_item_plot(df_store_item, df_store_item_worst.store_item_id.values[-2])
v4 = get_store_item_plot(df_store_item, df_store_item_worst.store_item_id.values[-3])
v5 = get_store_item_plot(df_store_item, df_store_item_worst.store_item_id.values[-4])
v6 = get_store_item_plot(df_store_item, df_store_item_worst.store_item_id.values[-5])
v7 = get_store_item_plot(df_store_item, df_store_item_worst.store_item_id.values[-6])
v8 = get_store_item_plot(df_store_item, df_store_item_worst.store_item_id.values[-7])
v9 = get_store_item_plot(df_store_item, df_store_item_worst.store_item_id.values[-8])
v10 = get_store_item_plot(df_store_item, df_store_item_worst.store_item_id.values[-9])
v11 = get_store_item_plot(df_store_item, df_store_item_worst.store_item_id.values[-10])


show(column(v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11))

# %% [markdown]
# ## 2. State-Item
# Let's look at the most relevant state-item combinations of interest.

# %%
df_state_item = evaluator.get_scores(preds_valid, 11)
df_state_item["state_item_id"] = df_state_item.state_id + "-" + df_state_item.item_id

df_state_item_best = df_state_item.sort_values("score_weighted").head(10).rename(columns = {"score_weighted": "score_best"})
df_state_item_worst = df_state_item.sort_values("score_weighted", ascending = False).head(10).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_state_item_best_worst = pd.concat([df_state_item_best, df_state_item_worst])

source_1 = ColumnDataSource(data = dict(
    state_item_id = df_state_item_best_worst.state_item_id.values,
    score_best = df_state_item_best_worst.score_best.values,
    score_worst = df_state_item_best_worst.score_worst.values
))

tooltips_1 = [
    ("state-Item", "@state_item_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("state-Item", "@state_item_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_state_item_best_worst.state_item_id.values, title = "Best and Worst state-Item")
v11 = v1.hbar("state_item_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("state_item_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "State-Item"


def get_state_item_plot(df, state_item_id):
    """
    Plots the actual and predicted values of state-item
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.state_item_id == state_item_id, actual_dates].values[0],
        predicted = df.loc[df.state_item_id == state_item_id, predicted_dates].values[0]
    ))
    
    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]
    
    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"state-item = {state_item_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4

    return v

v2 = get_state_item_plot(df_state_item, df_state_item_worst.state_item_id.values[-1])
v3 = get_state_item_plot(df_state_item, df_state_item_worst.state_item_id.values[-2])
v4 = get_state_item_plot(df_state_item, df_state_item_worst.state_item_id.values[-3])
v5 = get_state_item_plot(df_state_item, df_state_item_worst.state_item_id.values[-4])
v6 = get_state_item_plot(df_state_item, df_state_item_worst.state_item_id.values[-5])
v7 = get_state_item_plot(df_state_item, df_state_item_worst.state_item_id.values[-6])
v8 = get_state_item_plot(df_state_item, df_state_item_worst.state_item_id.values[-7])
v9 = get_state_item_plot(df_state_item, df_state_item_worst.state_item_id.values[-8])
v10 = get_state_item_plot(df_state_item, df_state_item_worst.state_item_id.values[-9])
v11 = get_state_item_plot(df_state_item, df_state_item_worst.state_item_id.values[-10])


show(column(v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11))

# %% [markdown]
# ## 3. Item
# Let's look at the most relevant items of interest.

# %%
df_item = evaluator.get_scores(preds_valid, 6)

df_item_best = df_item.sort_values("score_weighted").head(10).rename(columns = {"score_weighted": "score_best"})
df_item_worst = df_item.sort_values("score_weighted", ascending = False).head(10).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_item_best_worst = pd.concat([df_item_best, df_item_worst])

source_1 = ColumnDataSource(data = dict(
    item_id = df_item_best_worst.item_id.values,
    score_best = df_item_best_worst.score_best.values,
    score_worst = df_item_best_worst.score_worst.values
))

tooltips_1 = [
    ("Item", "@item_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("Item", "@item_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_item_best_worst.item_id.values, title = "Best and Worst Items")
v11 = v1.hbar("item_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("item_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "Item"


def get_item_plot(df, item_id):
    """
    Plots the actual and predicted values of item_id
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.item_id == item_id, actual_dates].values[0],
        predicted = df.loc[df.item_id == item_id, predicted_dates].values[0]
    ))
    
    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]
    
    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"item_id = {item_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4

    return v

v2 = get_item_plot(df_item, df_item_worst.item_id.values[-1])
v3 = get_item_plot(df_item, df_item_worst.item_id.values[-2])
v4 = get_item_plot(df_item, df_item_worst.item_id.values[-3])
v5 = get_item_plot(df_item, df_item_worst.item_id.values[-4])
v6 = get_item_plot(df_item, df_item_worst.item_id.values[-5])
v7 = get_item_plot(df_item, df_item_worst.item_id.values[-6])
v8 = get_item_plot(df_item, df_item_worst.item_id.values[-7])
v9 = get_item_plot(df_item, df_item_worst.item_id.values[-8])
v10 = get_item_plot(df_item, df_item_worst.item_id.values[-9])
v11 = get_item_plot(df_item, df_item_worst.item_id.values[-10])


show(column(v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11))

# %% [markdown]
# ## 4. Store-Department
# Let's look at the most relevant store-department combinations of interest.

# %%
df_store_dept = evaluator.get_scores(preds_valid, 10)
df_store_dept["store_dept_id"] = df_store_dept.store_id + "-" + df_store_dept.dept_id

df_store_dept_best = df_store_dept.sort_values("score_weighted").head(10).rename(columns = {"score_weighted": "score_best"})
df_store_dept_worst = df_store_dept.sort_values("score_weighted", ascending = False).head(10).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_store_dept_best_worst = pd.concat([df_store_dept_best, df_store_dept_worst])

source_1 = ColumnDataSource(data = dict(
    store_dept_id = df_store_dept_best_worst.store_dept_id.values,
    score_best = df_store_dept_best_worst.score_best.values,
    score_worst = df_store_dept_best_worst.score_worst.values
))

tooltips_1 = [
    ("Store-dept", "@store_dept_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("Store-dept", "@store_dept_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_store_dept_best_worst.store_dept_id.values, title = "Best and Worst Store-dept")
v11 = v1.hbar("store_dept_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("store_dept_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "Store-Department"


def get_store_dept_plot(df, store_dept_id):
    """
    Plots the actual and predicted values of store-dept
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.store_dept_id == store_dept_id, actual_dates].values[0],
        predicted = df.loc[df.store_dept_id == store_dept_id, predicted_dates].values[0]
    ))
    
    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]
    
    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"store-dept = {store_dept_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4

    return v

v2 = get_store_dept_plot(df_store_dept, df_store_dept_worst.store_dept_id.values[-1])
v3 = get_store_dept_plot(df_store_dept, df_store_dept_worst.store_dept_id.values[-2])
v4 = get_store_dept_plot(df_store_dept, df_store_dept_worst.store_dept_id.values[-3])
v5 = get_store_dept_plot(df_store_dept, df_store_dept_worst.store_dept_id.values[-4])
v6 = get_store_dept_plot(df_store_dept, df_store_dept_worst.store_dept_id.values[-5])
v7 = get_store_dept_plot(df_store_dept, df_store_dept_worst.store_dept_id.values[-6])
v8 = get_store_dept_plot(df_store_dept, df_store_dept_worst.store_dept_id.values[-7])
v9 = get_store_dept_plot(df_store_dept, df_store_dept_worst.store_dept_id.values[-8])
v10 = get_store_dept_plot(df_store_dept, df_store_dept_worst.store_dept_id.values[-9])
v11 = get_store_dept_plot(df_store_dept, df_store_dept_worst.store_dept_id.values[-10])


show(column(v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11))

# %% [markdown]
# ## 5. Store-Category
# Let's look at the most relevant store-category combinations of interest.

# %%
df_store_cat = evaluator.get_scores(preds_valid, 9)
df_store_cat["store_cat_id"] = df_store_cat.store_id + "-" + df_store_cat.cat_id

df_store_cat_best = df_store_cat.sort_values("score_weighted").head(10).rename(columns = {"score_weighted": "score_best"})
df_store_cat_worst = df_store_cat.sort_values("score_weighted", ascending = False).head(10).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_store_cat_best_worst = pd.concat([df_store_cat_best, df_store_cat_worst])

source_1 = ColumnDataSource(data = dict(
    store_cat_id = df_store_cat_best_worst.store_cat_id.values,
    score_best = df_store_cat_best_worst.score_best.values,
    score_worst = df_store_cat_best_worst.score_worst.values
))

tooltips_1 = [
    ("Store-cat", "@store_cat_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("Store-cat", "@store_cat_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_store_cat_best_worst.store_cat_id.values, title = "Best and Worst Store-cat")
v11 = v1.hbar("store_cat_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("store_cat_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "Store-Category"


def get_store_cat_plot(df, store_cat_id):
    """
    Plots the actual and predicted values of store-cat
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.store_cat_id == store_cat_id, actual_dates].values[0],
        predicted = df.loc[df.store_cat_id == store_cat_id, predicted_dates].values[0]
    ))
    
    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]
    
    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"store-cat = {store_cat_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4

    return v

v2 = get_store_cat_plot(df_store_cat, df_store_cat_worst.store_cat_id.values[-1])
v3 = get_store_cat_plot(df_store_cat, df_store_cat_worst.store_cat_id.values[-2])
v4 = get_store_cat_plot(df_store_cat, df_store_cat_worst.store_cat_id.values[-3])
v5 = get_store_cat_plot(df_store_cat, df_store_cat_worst.store_cat_id.values[-4])
v6 = get_store_cat_plot(df_store_cat, df_store_cat_worst.store_cat_id.values[-5])
v7 = get_store_cat_plot(df_store_cat, df_store_cat_worst.store_cat_id.values[-6])
v8 = get_store_cat_plot(df_store_cat, df_store_cat_worst.store_cat_id.values[-7])
v9 = get_store_cat_plot(df_store_cat, df_store_cat_worst.store_cat_id.values[-8])
v10 = get_store_cat_plot(df_store_cat, df_store_cat_worst.store_cat_id.values[-9])
v11 = get_store_cat_plot(df_store_cat, df_store_cat_worst.store_cat_id.values[-10])


show(column(v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11))

# %% [markdown]
# ## 6. State-Department
# Let's look at the most relevant state-department combinations of interest.

# %%
df_state_dept = evaluator.get_scores(preds_valid, 8)
df_state_dept["state_dept_id"] = df_state_dept.state_id + "-" + df_state_dept.dept_id

df_state_dept_best = df_state_dept.sort_values("score_weighted").head(10).rename(columns = {"score_weighted": "score_best"})
df_state_dept_worst = df_state_dept.sort_values("score_weighted", ascending = False).head(10).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_state_dept_best_worst = pd.concat([df_state_dept_best, df_state_dept_worst])

source_1 = ColumnDataSource(data = dict(
    state_dept_id = df_state_dept_best_worst.state_dept_id.values,
    score_best = df_state_dept_best_worst.score_best.values,
    score_worst = df_state_dept_best_worst.score_worst.values
))

tooltips_1 = [
    ("state-dept", "@state_dept_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("state-dept", "@state_dept_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_state_dept_best_worst.state_dept_id.values, title = "Best and Worst state-dept")
v11 = v1.hbar("state_dept_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("state_dept_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "State-Department"


def get_state_dept_plot(df, state_dept_id):
    """
    Plots the actual and predicted values of state-dept
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.state_dept_id == state_dept_id, actual_dates].values[0],
        predicted = df.loc[df.state_dept_id == state_dept_id, predicted_dates].values[0]
    ))
    
    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]
    
    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"state-dept = {state_dept_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4

    return v

v2 = get_state_dept_plot(df_state_dept, df_state_dept_worst.state_dept_id.values[-1])
v3 = get_state_dept_plot(df_state_dept, df_state_dept_worst.state_dept_id.values[-2])
v4 = get_state_dept_plot(df_state_dept, df_state_dept_worst.state_dept_id.values[-3])
v5 = get_state_dept_plot(df_state_dept, df_state_dept_worst.state_dept_id.values[-4])
v6 = get_state_dept_plot(df_state_dept, df_state_dept_worst.state_dept_id.values[-5])
v7 = get_state_dept_plot(df_state_dept, df_state_dept_worst.state_dept_id.values[-6])
v8 = get_state_dept_plot(df_state_dept, df_state_dept_worst.state_dept_id.values[-7])
v9 = get_state_dept_plot(df_state_dept, df_state_dept_worst.state_dept_id.values[-8])
v10 = get_state_dept_plot(df_state_dept, df_state_dept_worst.state_dept_id.values[-9])
v11 = get_state_dept_plot(df_state_dept, df_state_dept_worst.state_dept_id.values[-10])


show(column(v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11))

# %% [markdown]
# ## 7. Store
# Let's look at all the 10 stores.

# %%
df_store = evaluator.get_scores(preds_valid, 5)

df_store_best = df_store.sort_values("score_weighted").head(5).rename(columns = {"score_weighted": "score_best"})
df_store_worst = df_store.sort_values("score_weighted", ascending = False).head(5).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_store_best_worst = pd.concat([df_store_best, df_store_worst])

source_1 = ColumnDataSource(data = dict(
    store_id = df_store_best_worst.store_id.values,
    score_best = df_store_best_worst.score_best.values,
    score_worst = df_store_best_worst.score_worst.values
))

tooltips_1 = [
    ("store", "@store_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("store", "@store_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_store_best_worst.store_id.values, title = "Best and Worst stores")
v11 = v1.hbar("store_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("store_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "Store"


def get_store_plot(df, store_id):
    """
    Plots the actual and predicted values of store_id
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.store_id == store_id, actual_dates].values[0],
        predicted = df.loc[df.store_id == store_id, predicted_dates].values[0]
    ))
    
    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]
    
    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"store_id = {store_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4

    return v

v2 = get_store_plot(df_store, df_store_best_worst.store_id.values[-1])
v3 = get_store_plot(df_store, df_store_best_worst.store_id.values[-2])
v4 = get_store_plot(df_store, df_store_best_worst.store_id.values[-3])
v5 = get_store_plot(df_store, df_store_best_worst.store_id.values[-4])
v6 = get_store_plot(df_store, df_store_best_worst.store_id.values[-5])
v7 = get_store_plot(df_store, df_store_best_worst.store_id.values[-6])
v8 = get_store_plot(df_store, df_store_best_worst.store_id.values[-7])
v9 = get_store_plot(df_store, df_store_best_worst.store_id.values[-8])
v10 = get_store_plot(df_store, df_store_best_worst.store_id.values[-9])
v11 = get_store_plot(df_store, df_store_best_worst.store_id.values[-10])


show(column(v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11))

# %% [markdown]
# ## 8. Department
# Let's look at all the 7 departments.

# %%
df_dept = evaluator.get_scores(preds_valid, 4)

df_dept_best = df_dept.sort_values("score_weighted").head(3).rename(columns = {"score_weighted": "score_best"})
df_dept_worst = df_dept.sort_values("score_weighted", ascending = False).head(4).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_dept_best_worst = pd.concat([df_dept_best, df_dept_worst])

source_1 = ColumnDataSource(data = dict(
    dept_id = df_dept_best_worst.dept_id.values,
    score_best = df_dept_best_worst.score_best.values,
    score_worst = df_dept_best_worst.score_worst.values
))

tooltips_1 = [
    ("dept", "@dept_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("dept", "@dept_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_dept_best_worst.dept_id.values, title = "Best and Worst depts")
v11 = v1.hbar("dept_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("dept_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "Department"


def get_dept_plot(df, dept_id):
    """
    Plots the actual and predicted values of dept_id
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.dept_id == dept_id, actual_dates].values[0],
        predicted = df.loc[df.dept_id == dept_id, predicted_dates].values[0]
    ))

    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]

    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"dept_id = {dept_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4

    return v

v2 = get_dept_plot(df_dept, df_dept_best_worst.dept_id.values[-1])
v3 = get_dept_plot(df_dept, df_dept_best_worst.dept_id.values[-2])
v4 = get_dept_plot(df_dept, df_dept_best_worst.dept_id.values[-3])
v5 = get_dept_plot(df_dept, df_dept_best_worst.dept_id.values[-4])
v6 = get_dept_plot(df_dept, df_dept_best_worst.dept_id.values[-5])
v7 = get_dept_plot(df_dept, df_dept_best_worst.dept_id.values[-6])
v8 = get_dept_plot(df_dept, df_dept_best_worst.dept_id.values[-7])


show(column(v1, v2, v3, v4, v5, v6, v7, v8))

# %% [markdown]
# ## 9. State-Category
# Let's look at all the 9 state-category combinations.

# %%
df_state_cat = evaluator.get_scores(preds_valid, 7)
df_state_cat["state_cat_id"] = df_state_cat.state_id + "-" + df_state_cat.cat_id

df_state_cat_best = df_state_cat.sort_values("score_weighted").head(4).rename(columns = {"score_weighted": "score_best"})
df_state_cat_worst = df_state_cat.sort_values("score_weighted", ascending = False).head(5).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_state_cat_best_worst = pd.concat([df_state_cat_best, df_state_cat_worst])

source_1 = ColumnDataSource(data = dict(
    state_cat_id = df_state_cat_best_worst.state_cat_id.values,
    score_best = df_state_cat_best_worst.score_best.values,
    score_worst = df_state_cat_best_worst.score_worst.values
))

tooltips_1 = [
    ("state-cat", "@state_cat_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("state-cat", "@state_cat_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_state_cat_best_worst.state_cat_id.values, title = "Best and Worst state-cat")
v11 = v1.hbar("state_cat_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("state_cat_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "State-Category"


def get_state_cat_plot(df, state_cat_id):
    """
    Plots the actual and predicted values of state-cat
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.state_cat_id == state_cat_id, actual_dates].values[0],
        predicted = df.loc[df.state_cat_id == state_cat_id, predicted_dates].values[0]
    ))
    
    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]
    
    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"state-cat = {state_cat_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4

    return v

v2 = get_state_cat_plot(df_state_cat, df_state_cat_best_worst.state_cat_id.values[-1])
v3 = get_state_cat_plot(df_state_cat, df_state_cat_best_worst.state_cat_id.values[-2])
v4 = get_state_cat_plot(df_state_cat, df_state_cat_best_worst.state_cat_id.values[-3])
v5 = get_state_cat_plot(df_state_cat, df_state_cat_best_worst.state_cat_id.values[-4])
v6 = get_state_cat_plot(df_state_cat, df_state_cat_best_worst.state_cat_id.values[-5])
v7 = get_state_cat_plot(df_state_cat, df_state_cat_best_worst.state_cat_id.values[-6])
v8 = get_state_cat_plot(df_state_cat, df_state_cat_best_worst.state_cat_id.values[-7])
v9 = get_state_cat_plot(df_state_cat, df_state_cat_best_worst.state_cat_id.values[-8])
v10 = get_state_cat_plot(df_state_cat, df_state_cat_best_worst.state_cat_id.values[-9])


show(column(v1, v2, v3, v4, v5, v6, v7, v8, v9, v10))

# %% [markdown]
# ## 10. State
# Let's look at all the 3 states.

# %%
df_state = evaluator.get_scores(preds_valid, 3)

df_state_best = df_state.sort_values("score_weighted").head(1).rename(columns = {"score_weighted": "score_best"})
df_state_worst = df_state.sort_values("score_weighted", ascending = False).head(2).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_state_best_worst = pd.concat([df_state_best, df_state_worst])

source_1 = ColumnDataSource(data = dict(
    state_id = df_state_best_worst.state_id.values,
    score_best = df_state_best_worst.score_best.values,
    score_worst = df_state_best_worst.score_worst.values
))

tooltips_1 = [
    ("state", "@state_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("state", "@state_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_state_best_worst.state_id.values, title = "Best and Worst states")
v11 = v1.hbar("state_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("state_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "State"


def get_state_plot(df, state_id):
    """
    Plots the actual and predicted values of state_id
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.state_id == state_id, actual_dates].values[0],
        predicted = df.loc[df.state_id == state_id, predicted_dates].values[0]
    ))

    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]
    
    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"state_id = {state_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4

    return v

v2 = get_state_plot(df_state, df_state_best_worst.state_id.values[-1])
v3 = get_state_plot(df_state, df_state_best_worst.state_id.values[-2])
v4 = get_state_plot(df_state, df_state_best_worst.state_id.values[-3])


show(column(v1, v2, v3, v4))

# %% [markdown]
# ## 11. Category
# Let's look at all the 3 categories.

# %%
df_cat = evaluator.get_scores(preds_valid, 2)

df_cat_best = df_cat.sort_values("score_weighted").head(1).rename(columns = {"score_weighted": "score_best"})
df_cat_worst = df_cat.sort_values("score_weighted", ascending = False).head(2).sort_values("score_weighted").rename(columns = {"score_weighted": "score_worst"})

df_cat_best_worst = pd.concat([df_cat_best, df_cat_worst])

source_1 = ColumnDataSource(data = dict(
    cat_id = df_cat_best_worst.cat_id.values,
    score_best = df_cat_best_worst.score_best.values,
    score_worst = df_cat_best_worst.score_worst.values
))

tooltips_1 = [
    ("cat", "@cat_id"),
    ("Score", "@score_best{0.0000}")
]

tooltips_2 = [
    ("cat", "@cat_id"),
    ("Score", "@score_worst{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 400, y_range = df_cat_best_worst.cat_id.values, title = "Best and Worst cats")
v11 = v1.hbar("cat_id", right = "score_best", source = source_1, height = 0.75, alpha = 0.6, color = "green")
v12 = v1.hbar("cat_id", right = "score_worst", source = source_1, height = 0.75, alpha = 0.6, color = "red")

v1.add_tools(HoverTool(renderers = [v11], tooltips = tooltips_1))
v1.add_tools(HoverTool(renderers = [v12], tooltips = tooltips_2))

v1.xaxis.axis_label = "WRMSSE Score"
v1.yaxis.axis_label = "Category"


def get_cat_plot(df, cat_id):
    """
    Plots the actual and predicted values of cat_id
    """
    actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
    predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]
    
    source = ColumnDataSource(data = dict(
        date_number = actual_dates,
        date = LB_DATES,
        weekday = LB_WEEKDAYS,
        actual = df.loc[df.cat_id == cat_id, actual_dates].values[0],
        predicted = df.loc[df.cat_id == cat_id, predicted_dates].values[0]
    ))
    
    tooltips = [
        ("Date", "@date"),
        ("Weekday", "@weekday"),
        ("Actual", "@actual{0}"),
        ("Predicted", "@predicted{0.0}")
    ]

    v = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = f"cat_id = {cat_id}")
    v.line("date_number", "actual", source = source, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
    v.line("date_number", "predicted", source = source, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

    v.xaxis.major_label_orientation = pi / 4

    return v

v2 = get_cat_plot(df_cat, df_cat_best_worst.cat_id.values[-1])
v3 = get_cat_plot(df_cat, df_cat_best_worst.cat_id.values[-2])
v4 = get_cat_plot(df_cat, df_cat_best_worst.cat_id.values[-3])


show(column(v1, v2, v3, v4))

# %% [markdown]
# ## 12. All
# Let's look at all levels aggregated together.

# %%
df = evaluator.get_scores(preds_valid, 1)

source_1 = ColumnDataSource(data = dict(
    level = ["All"],
    score = df.score_weighted.values
))

tooltips_1 = [
    ("Level", "all"),
    ("Score", "@score{0.0000}")
]

v1 = figure(plot_width = 700, plot_height = 200, y_range = ["All"], tooltips = tooltips_1, title = "All levels")
v1.hbar("level", right = "score", source = source_1, height = 0.5, alpha = 0.6, color = "red")

v1.xaxis.axis_label = "WRMSSE Score"

actual_dates = ["d_" + str(x) for x in range(1914, 1942)]
predicted_dates = ["pred_d_" + str(x) for x in range(1914, 1942)]

source_2 = ColumnDataSource(data = dict(
    date_number = actual_dates,
    date = LB_DATES,
    weekday = LB_WEEKDAYS,
    actual = df[actual_dates].values[0],
    predicted = df[predicted_dates].values[0]
))
    
tooltips = [
    ("Date", "@date"),
    ("Weekday", "@weekday"),
    ("Actual", "@actual{0}"),
    ("Predicted", "@predicted{0.0}")
]
    
    
v2 = figure(plot_width = 700, plot_height = 400, x_range = actual_dates, tooltips = tooltips, title = "All levels")
v2.line("date_number", "actual", source = source_2, color = "steelblue", alpha = 0.6, width = 3, legend_label = "Actual")
v2.line("date_number", "predicted", source = source_2, color = "coral", alpha = 0.6, width = 3, legend_label = "Predicted")

v2.xaxis.major_label_orientation = pi / 4

show(column(v1, v2))

# %% [markdown]
# ## Anatomy to Action
# It's not just about summarizing and plotting these graphs. It's about extracting insights from them and convert them to code/actions that can help in improving the model's performance on the private test data. Not just to overfit the public LB.
#
# Good Luck!
